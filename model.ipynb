# %%
import numpy as np
import random

# %%
# Подписчики
class Subscriber:
    def __init__(self, id, num_channels):
        self.id = id
        self.subscribed_channels = set(random.sample(range(num_channels), np.random.randint(1, 11)))

# %%
# Каналы
class Channel:
    def __init__(self, id):
        self.id = id
        self.subscribers = 0
        self.connections = []
        self.is_sensitive = self.generate_post()

    def generate_post(self):
        return np.random.binomial(1, 0.3) == 1

    def choose_strategy(self, total_subs, expected_sub_growth):

        U_sensitive = self.calculate_payoff(total_subs, expected_sub_growth, sensitive=True)
        U_informative = self.calculate_payoff(total_subs, expected_sub_growth, sensitive=False)

        if self.is_sensitive:
            self.is_sensitive = U_sensitive > U_informative
        else:
            self.is_sensitive = U_informative >= U_sensitive

    def calculate_payoff(self, total_subs, expected_sub_growth, sensitive):
        
        if sensitive:
            payoff = (self.subscribers / total_subs) * (-self.subscribers) + \
                     (1 - (self.subscribers / total_subs)) * (self.subscribers + expected_sub_growth)
        else:
            payoff = (self.subscribers / total_subs) * self.subscribers
        
        return payoff

    def update_subscribers(self, nearby_channels, total_subs):
        if self.is_sensitive:
            for n_ch in nearby_channels:
                if not n_ch.is_sensitive:
                    gain_prob = self.subscribers / (n_ch.subscribers + self.subscribers)
                    subscribers_to_gain = int(gain_prob * n_ch.subscribers)
                    n_ch.subscribers -= subscribers_to_gain
                    self.subscribers += subscribers_to_gain

# %%
# Модель
class Model:
    def __init__(self, num_channels):
        self.channels = [Channel(i) for i in range(num_channels)]

    # Генерация сети
    def generate_connections(self):
        print("Сеть каналов:\n")
        for i, channel in enumerate(self.channels):
            for j in range(i + 1, len(self.channels)):
                if np.random.rand() < 0.5:
                    con = np.random.poisson(10)
                    channel.connections.append(self.channels[j])
                    print("Каналы", i, "&", j, "-", con, "\n")

                if np.random.rand() < 0.5:
                    con = np.random.poisson(10)
                    self.channels[j].connections.append(channel)
                    print("Каналы", j, "&", i, "-", con, "\n")

    # Процесс симуляции (10 раундов)
    def simulate(self, num_subscribers, regulator):
        
        subscribers = [Subscriber(i, len(self.channels)) for i in range(num_subscribers)]
        
        print("Стартовое распределение\n")
        for s in subscribers:
            for ch in s.subscribed_channels:
                self.channels[ch].subscribers += 1
        for channel in self.channels:
            print("Канал", channel.id, ":", channel.subscribers, "подп.\n")

        total_subs = sum(channel.subscribers for channel in self.channels)

        for round in range(10):
            print("Раунд", round + 1, "\n")
            for channel in self.channels:
                expected_sub_growth = 0
                channel.choose_strategy(total_subs, expected_sub_growth)
                if channel.is_sensitive:
                    print("Канал", channel.id, "публикует сенситивный пост.\n")
                else:
                    print("Канал", channel.id, "публикует информативный пост.\n")
                            
            regulator.monitor_channels(self.channels, total_subs)
                            
            for channel in self.channels:
                if channel.is_sensitive:
                    channel.update_subscribers(channel.connections, total_subs)
                            
            total_subs = sum(channel.subscribers for channel in self.channels)
            print("\n")
            for channel in self.channels:
                print("Канал", channel.id, ":", channel.subscribers, "подп.\n")

# %%
# Действия регулятора
class Regulator:
    def monitor_channels(self, channels, total_subs):
        for channel in channels:
            if channel.is_sensitive and np.random.rand() < (channel.subscribers / total_subs):
                print("Канал", channel.id, "заблокирован\n")
                channels.remove(channel)

# %%
# Пробую посмотреть промежуточные результаты на тесте симуляции
num_channels = 100
num_subscribers = 5000

# Генерим сначала сеть
model = Model(num_channels)
model.generate_connections()

# Смотрим саму модель
regulator = Regulator()
model.simulate(num_subscribers, regulator)
# Out:
# Сеть каналов:
#
# Каналы 0 & 1 - 8
#
# Каналы 1 & 0 - 13
#
# Каналы 0 & 3 - 16
#
# Каналы 4 & 0 - 8
#
# Каналы 0 & 5 - 8
#
# Каналы 5 & 0 - 6
#
# Каналы 0 & 6 - 8
#
# Каналы 6 & 0 - 14
#
# Каналы 7 & 0 - 9
#
# Каналы 0 & 8 - 8
#
# Каналы 0 & 9 - 14
#
# Каналы 9 & 0 - 9
#
# Каналы 10 & 0 - 6
#
# Каналы 0 & 11 - 8
#
# Каналы 11 & 0 - 7
#
# Каналы 0 & 12 - 10
#
# Каналы 12 & 0 - 12
#
# Каналы 0 & 13 - 6
#
# Каналы 13 & 0 - 10
#
# Каналы 14 & 0 - 8
#
# Каналы 0 & 15 - 9
#
# Каналы 15 & 0 - 11
#
# Каналы 0 & 16 - 9
#
# Каналы 16 & 0 - 9
#
# Каналы 17 & 0 - 6
#
# Каналы 0 & 19 - 11
#
# Каналы 0 & 21 - 9
#
# Каналы 22 & 0 - 12
#
# Каналы 23 & 0 - 6
#
# Каналы 25 & 0 - 9
#
# Каналы 0 & 27 - 15
#
# Каналы 27 & 0 - 9
#
# Каналы 0 & 28 - 9
#
# Каналы 28 & 0 - 8
#
# Каналы 30 & 0 - 8
#
# Каналы 34 & 0 - 6
#
# Каналы 0 & 35 - 10
#
# Каналы 35 & 0 - 6
#
# Каналы 37 & 0 - 15
#
# Каналы 0 & 39 - 5
#
# Каналы 0 & 40 - 7
#
# Каналы 40 & 0 - 10
#
# Каналы 0 & 42 - 17
#
# Каналы 42 & 0 - 13
#
# Каналы 0 & 43 - 10
#
# Каналы 0 & 44 - 15
#
# Каналы 44 & 0 - 10
#
# Каналы 45 & 0 - 8
#
# Каналы 46 & 0 - 10
#
# Каналы 0 & 47 - 12
#
# Каналы 47 & 0 - 2
#
# Каналы 0 & 48 - 11
#
# Каналы 48 & 0 - 5
#
# Каналы 0 & 50 - 9
#
# Каналы 51 & 0 - 14
#
# Каналы 52 & 0 - 10
#
# Каналы 0 & 54 - 15
#
# Каналы 54 & 0 - 12
#
# Каналы 0 & 56 - 16
#
# Каналы 58 & 0 - 5
#
# Каналы 0 & 59 - 8
#
# Каналы 59 & 0 - 11
#
# Каналы 0 & 60 - 14
#
# Каналы 0 & 61 - 5
#
# Каналы 0 & 63 - 13
#
# Каналы 63 & 0 - 12
#
# Каналы 0 & 64 - 5
#
# Каналы 65 & 0 - 11
#
# Каналы 0 & 67 - 5
#
# Каналы 67 & 0 - 10
#
# Каналы 0 & 68 - 13
#
# Каналы 68 & 0 - 13
#
# Каналы 0 & 72 - 9
#
# Каналы 0 & 76 - 11
#
# Каналы 78 & 0 - 16
#
# Каналы 0 & 79 - 14
#
# Каналы 0 & 80 - 6
#
# Каналы 80 & 0 - 18
#
# Каналы 0 & 81 - 7
#
# Каналы 81 & 0 - 13
#
# Каналы 0 & 83 - 10
#
# Каналы 0 & 84 - 6
#
# Каналы 84 & 0 - 10
#
# Каналы 0 & 85 - 9
#
# Каналы 85 & 0 - 5
#
# Каналы 0 & 86 - 13
#
# Каналы 86 & 0 - 11
#
# Каналы 0 & 88 - 15
#
# Каналы 89 & 0 - 8
#
# Каналы 0 & 90 - 11
#
# Каналы 0 & 91 - 11
#
# Каналы 91 & 0 - 9
#
# Каналы 0 & 92 - 8
#
# Каналы 92 & 0 - 14
#
# Каналы 0 & 95 - 11
#
# Каналы 95 & 0 - 11
#
# Каналы 96 & 0 - 14
#
# Каналы 0 & 98 - 11
#
# Каналы 0 & 99 - 9
#
# Каналы 1 & 2 - 8
#
# Каналы 3 & 1 - 6
#
# Каналы 1 & 5 - 11
#
# Каналы 1 & 6 - 9
#
# Каналы 6 & 1 - 11
#
# Каналы 1 & 7 - 10
#
# Каналы 7 & 1 - 19
#
# Каналы 1 & 10 - 8
#
# Каналы 10 & 1 - 7
#
# Каналы 1 & 11 - 14
#
# Каналы 11 & 1 - 6
#
# Каналы 1 & 12 - 13
#
# Каналы 13 & 1 - 10
#
# Каналы 15 & 1 - 10
#
# Каналы 1 & 16 - 7
#
# Каналы 16 & 1 - 10
#
# Каналы 18 & 1 - 6
#
# Каналы 19 & 1 - 12
#
# Каналы 1 & 20 - 11
#
# Каналы 20 & 1 - 3
#
# Каналы 1 & 22 - 13
#
# Каналы 1 & 24 - 13
#
# Каналы 24 & 1 - 16
#
# Каналы 1 & 27 - 9
#
# Каналы 28 & 1 - 11
#
# Каналы 30 & 1 - 11
#
# Каналы 1 & 31 - 10
#
# Каналы 1 & 32 - 9
#
# Каналы 32 & 1 - 10
#
# Каналы 1 & 34 - 4
#
# Каналы 34 & 1 - 5
#
# Каналы 36 & 1 - 8
#
# Каналы 1 & 37 - 12
#
# Каналы 37 & 1 - 16
#
# Каналы 1 & 38 - 8
#
# Каналы 39 & 1 - 14
#
# Каналы 1 & 41 - 10
#
# Каналы 1 & 42 - 8
#
# Каналы 42 & 1 - 8
#
# Каналы 1 & 45 - 10
#
# Каналы 1 & 46 - 8
#
# Каналы 1 & 47 - 4
#
# Каналы 49 & 1 - 16
#
# Каналы 50 & 1 - 13
#
# Каналы 1 & 51 - 14
#
# Каналы 51 & 1 - 5
#
# Каналы 52 & 1 - 9
#
# Каналы 1 & 54 - 11
#
# Каналы 54 & 1 - 11
#
# Каналы 55 & 1 - 7
#
# Каналы 56 & 1 - 13
#
# Каналы 57 & 1 - 8
#
# Каналы 1 & 58 - 10
#
# Каналы 58 & 1 - 9
#
# Каналы 1 & 60 - 3
#
# Каналы 60 & 1 - 8
#
# Каналы 1 & 62 - 8
#
# Каналы 62 & 1 - 14
#
# Каналы 1 & 63 - 11
#
# Каналы 63 & 1 - 8
#
# Каналы 1 & 64 - 16
#
# Каналы 64 & 1 - 10
#
# Каналы 1 & 65 - 9
#
# Каналы 1 & 66 - 17
#
# Каналы 66 & 1 - 10
#
# Каналы 67 & 1 - 13
#
# Каналы 1 & 68 - 19
#
# Каналы 69 & 1 - 14
#
# Каналы 70 & 1 - 5
#
# Каналы 1 & 72 - 10
#
# Каналы 72 & 1 - 8
#
# Каналы 73 & 1 - 10
#
# Каналы 1 & 74 - 4
#
# Каналы 74 & 1 - 11
#
# Каналы 1 & 75 - 6
#
# Каналы 1 & 77 - 13
#
# Каналы 78 & 1 - 9
#
# Каналы 1 & 79 - 9
#
# Каналы 1 & 80 - 12
#
# Каналы 1 & 83 - 7
#
# Каналы 84 & 1 - 11
#
# Каналы 1 & 85 - 12
#
# Каналы 86 & 1 - 7
#
# Каналы 87 & 1 - 12
#
# Каналы 88 & 1 - 6
#
# Каналы 1 & 91 - 12
#
# Каналы 1 & 94 - 6
#
# Каналы 94 & 1 - 5
#
# Каналы 95 & 1 - 9
#
# Каналы 96 & 1 - 6
#
# Каналы 1 & 97 - 13
#
# Каналы 97 & 1 - 12
#
# Каналы 98 & 1 - 5
#
# Каналы 1 & 99 - 6
#
# Каналы 2 & 3 - 10
#
# Каналы 2 & 4 - 15
#
# Каналы 4 & 2 - 11
#
# Каналы 2 & 5 - 11
#
# Каналы 5 & 2 - 12
#
# Каналы 2 & 6 - 10
#
# Каналы 2 & 7 - 12
#
# Каналы 2 & 9 - 12
#
# Каналы 2 & 10 - 11
#
# Каналы 2 & 11 - 14
#
# Каналы 11 & 2 - 12
#
# Каналы 12 & 2 - 6
#
# Каналы 2 & 13 - 4
#
# Каналы 13 & 2 - 11
#
# Каналы 14 & 2 - 17
#
# Каналы 15 & 2 - 11
#
# Каналы 17 & 2 - 8
#
# Каналы 2 & 18 - 10
#
# Каналы 18 & 2 - 9
#
# Каналы 2 & 19 - 8
#
# Каналы 19 & 2 - 11
#
# Каналы 2 & 21 - 15
#
# Каналы 21 & 2 - 8
#
# Каналы 2 & 24 - 11
#
# Каналы 24 & 2 - 10
#
# Каналы 2 & 25 - 11
#
# Каналы 26 & 2 - 13
#
# Каналы 2 & 27 - 10
#
# Каналы 27 & 2 - 10
#
# Каналы 2 & 28 - 7
#
# Каналы 2 & 29 - 15
#
# Каналы 29 & 2 - 13
#
# Каналы 30 & 2 - 7
#
# Каналы 31 & 2 - 15
#
# Каналы 32 & 2 - 5
#
# Каналы 33 & 2 - 8
#
# Каналы 2 & 34 - 12
#
# Каналы 34 & 2 - 13
#
# Каналы 2 & 35 - 11
#
# Каналы 2 & 36 - 3
#
# Каналы 2 & 37 - 10
#
# Каналы 38 & 2 - 8
#
# Каналы 2 & 39 - 8
#
# Каналы 39 & 2 - 6
#
# Каналы 2 & 40 - 11
#
# Каналы 2 & 41 - 15
#
# Каналы 41 & 2 - 15
#
# Каналы 43 & 2 - 13
#
# Каналы 44 & 2 - 7
#
# Каналы 45 & 2 - 13
#
# Каналы 2 & 46 - 14
#
# Каналы 46 & 2 - 9
#
# Каналы 2 & 47 - 10
#
# Каналы 2 & 48 - 8
#
# Каналы 2 & 49 - 10
#
# Каналы 2 & 50 - 12
#
# Каналы 51 & 2 - 10
#
# Каналы 52 & 2 - 6
#
# Каналы 2 & 53 - 9
#
# Каналы 54 & 2 - 8
#
# Каналы 2 & 56 - 13
#
# Каналы 57 & 2 - 13
#
# Каналы 59 & 2 - 11
#
# Каналы 2 & 60 - 13
#
# Каналы 60 & 2 - 11
#
# Каналы 2 & 61 - 11
#
# Каналы 62 & 2 - 10
#
# Каналы 63 & 2 - 8
#
# Каналы 64 & 2 - 8
#
# Каналы 66 & 2 - 15
#
# Каналы 67 & 2 - 8
#
# Каналы 68 & 2 - 10
#
# Каналы 70 & 2 - 10
#
# Каналы 71 & 2 - 11
#
# Каналы 2 & 73 - 16
#
# Каналы 2 & 74 - 10
#
# Каналы 74 & 2 - 10
#
# Каналы 2 & 75 - 7
#
# Каналы 75 & 2 - 7
#
# Каналы 2 & 76 - 13
#
# Каналы 76 & 2 - 9
#
# Каналы 2 & 77 - 7
#
# Каналы 77 & 2 - 7
#
# Каналы 2 & 78 - 10
#
# Каналы 78 & 2 - 13
#
# Каналы 2 & 81 - 9
#
# Каналы 81 & 2 - 8
#
# Каналы 82 & 2 - 13
#
# Каналы 84 & 2 - 9
#
# Каналы 2 & 85 - 8
#
# Каналы 85 & 2 - 9
#
# Каналы 2 & 86 - 9
#
# Каналы 2 & 87 - 10
#
# Каналы 87 & 2 - 12
#
# Каналы 2 & 89 - 13
#
# Каналы 89 & 2 - 11
#
# Каналы 2 & 91 - 13
#
# Каналы 91 & 2 - 8
#
# Каналы 92 & 2 - 10
#
# Каналы 2 & 94 - 13
#
# Каналы 95 & 2 - 12
#
# Каналы 96 & 2 - 9
#
# Каналы 2 & 97 - 13
#
# Каналы 99 & 2 - 8
#
# Каналы 3 & 4 - 10
#
# Каналы 4 & 3 - 7
#
# Каналы 5 & 3 - 14
#
# Каналы 3 & 6 - 13
#
# Каналы 6 & 3 - 6
#
# Каналы 3 & 7 - 13
#
# Каналы 8 & 3 - 11
#
# Каналы 3 & 10 - 18
#
# Каналы 10 & 3 - 13
#
# Каналы 11 & 3 - 7
#
# Каналы 12 & 3 - 13
#
# Каналы 14 & 3 - 12
#
# Каналы 16 & 3 - 4
#
# Каналы 18 & 3 - 14
#
# Каналы 19 & 3 - 9
#
# Каналы 3 & 21 - 7
#
# Каналы 21 & 3 - 7
#
# Каналы 3 & 22 - 14
#
# Каналы 22 & 3 - 16
#
# Каналы 3 & 23 - 14
#
# Каналы 3 & 24 - 5
#
# Каналы 3 & 25 - 12
#
# Каналы 25 & 3 - 12
#
# Каналы 27 & 3 - 10
#
# Каналы 29 & 3 - 9
#
# Каналы 3 & 31 - 6
#
# Каналы 3 & 32 - 11
#
# Каналы 32 & 3 - 13
#
# Каналы 33 & 3 - 9
#
# Каналы 34 & 3 - 11
#
# Каналы 3 & 36 - 13
#
# Каналы 36 & 3 - 7
#
# Каналы 37 & 3 - 8
#
# Каналы 3 & 39 - 10
#
# Каналы 3 & 40 - 15
#
# Каналы 41 & 3 - 12
#
# Каналы 3 & 42 - 12
#
# Каналы 44 & 3 - 7
#
# Каналы 45 & 3 - 10
#
# Каналы 3 & 46 - 3
#
# Каналы 48 & 3 - 11
#
# Каналы 3 & 49 - 13
#
# Каналы 50 & 3 - 9
#
# Каналы 3 & 51 - 22
#
# Каналы 51 & 3 - 15
#
# Каналы 3 & 52 - 13
#
# Каналы 52 & 3 - 10
#
# Каналы 3 & 53 - 12
#
# Каналы 53 & 3 - 8
#
# Каналы 3 & 54 - 9
#
# Каналы 3 & 56 - 8
#
# Каналы 56 & 3 - 10
#
# Каналы 59 & 3 - 12
#
# Каналы 60 & 3 - 12
#
# Каналы 3 & 61 - 14
#
# Каналы 3 & 62 - 18
#
# Каналы 62 & 3 - 11
#
# Каналы 3 & 63 - 7
#
# Каналы 3 & 64 - 8
#
# Каналы 64 & 3 - 6
#
# Каналы 3 & 65 - 10
#
# Каналы 65 & 3 - 15
#
# Каналы 3 & 66 - 14
#
# Каналы 66 & 3 - 10
#
# Каналы 68 & 3 - 7
#
# Каналы 3 & 69 - 8
#
# Каналы 3 & 70 - 8
#
# Каналы 70 & 3 - 10
#
# Каналы 71 & 3 - 8
#
# Каналы 3 & 72 - 14
#
# Каналы 73 & 3 - 4
#
# Каналы 3 & 74 - 9
#
# Каналы 3 & 75 - 4
#
# Каналы 75 & 3 - 10
#
# Каналы 3 & 76 - 11
#
# Каналы 76 & 3 - 7
#
# Каналы 77 & 3 - 12
#
# Каналы 3 & 78 - 5
#
# Каналы 3 & 79 - 10
#
# Каналы 79 & 3 - 11
#
# Каналы 3 & 80 - 5
#
# Каналы 3 & 81 - 13
#
# Каналы 3 & 83 - 8
#
# Каналы 85 & 3 - 12
#
# Каналы 3 & 87 - 14
#
# Каналы 3 & 88 - 7
#
# Каналы 89 & 3 - 10
#
# Каналы 90 & 3 - 4
#
# Каналы 91 & 3 - 9
#
# Каналы 92 & 3 - 5
#
# Каналы 3 & 93 - 11
#
# Каналы 93 & 3 - 13
#
# Каналы 94 & 3 - 10
#
# Каналы 95 & 3 - 15
#
# Каналы 3 & 96 - 11
#
# Каналы 96 & 3 - 5
#
# Каналы 3 & 97 - 13
#
# Каналы 3 & 98 - 6
#
# Каналы 98 & 3 - 8
#
# Каналы 5 & 4 - 6
#
# Каналы 4 & 9 - 9
#
# Каналы 9 & 4 - 10
#
# Каналы 4 & 12 - 13
#
# Каналы 4 & 13 - 11
#
# Каналы 14 & 4 - 13
#
# Каналы 4 & 15 - 10
#
# Каналы 15 & 4 - 8
#
# Каналы 4 & 16 - 13
#
# Каналы 4 & 18 - 12
#
# Каналы 18 & 4 - 7
#
# Каналы 19 & 4 - 9
#
# Каналы 4 & 20 - 8
#
# Каналы 20 & 4 - 6
#
# Каналы 4 & 22 - 5
#
# Каналы 22 & 4 - 11
#
# Каналы 4 & 23 - 13
#
# Каналы 4 & 24 - 11
#
# Каналы 4 & 26 - 10
#
# Каналы 26 & 4 - 16
#
# Каналы 27 & 4 - 13
#
# Каналы 4 & 28 - 8
#
# Каналы 30 & 4 - 5
#
# Каналы 31 & 4 - 12
#
# Каналы 4 & 32 - 16
#
# Каналы 4 & 33 - 8
#
# Каналы 4 & 34 - 5
#
# Каналы 4 & 36 - 6
#
# Каналы 36 & 4 - 9
#
# Каналы 4 & 37 - 8
#
# Каналы 4 & 38 - 11
#
# Каналы 4 & 39 - 10
#
# Каналы 4 & 40 - 8
#
# Каналы 4 & 41 - 14
#
# Каналы 41 & 4 - 8
#
# Каналы 4 & 42 - 9
#
# Каналы 42 & 4 - 11
#
# Каналы 43 & 4 - 9
#
# Каналы 4 & 44 - 9
#
# Каналы 44 & 4 - 6
#
# Каналы 4 & 45 - 14
#
# Каналы 4 & 46 - 13
#
# Каналы 47 & 4 - 13
#
# Каналы 4 & 49 - 10
#
# Каналы 49 & 4 - 14
#
# Каналы 50 & 4 - 13
#
# Каналы 51 & 4 - 14
#
# Каналы 4 & 53 - 6
#
# Каналы 57 & 4 - 11
#
# Каналы 4 & 58 - 14
#
# Каналы 58 & 4 - 8
#
# Каналы 4 & 60 - 7
#
# Каналы 61 & 4 - 10
#
# Каналы 4 & 62 - 13
#
# Каналы 4 & 63 - 13
#
# Каналы 63 & 4 - 9
#
# Каналы 4 & 64 - 14
#
# Каналы 4 & 65 - 9
#
# Каналы 4 & 66 - 5
#
# Каналы 66 & 4 - 6
#
# Каналы 4 & 67 - 8
#
# Каналы 4 & 68 - 17
#
# Каналы 68 & 4 - 5
#
# Каналы 69 & 4 - 9
#
# Каналы 70 & 4 - 11
#
# Каналы 4 & 71 - 9
#
# Каналы 71 & 4 - 11
#
# Каналы 72 & 4 - 13
#
# Каналы 4 & 73 - 13
#
# Каналы 74 & 4 - 11
#
# Каналы 75 & 4 - 14
#
# Каналы 76 & 4 - 11
#
# Каналы 77 & 4 - 12
#
# Каналы 4 & 78 - 4
#
# Каналы 79 & 4 - 11
#
# Каналы 4 & 80 - 16
#
# Каналы 82 & 4 - 7
#
# Каналы 4 & 83 - 6
#
# Каналы 83 & 4 - 4
#
# Каналы 4 & 84 - 10
#
# Каналы 84 & 4 - 9
#
# Каналы 4 & 85 - 8
#
# Каналы 4 & 87 - 14
#
# Каналы 88 & 4 - 9
#
# Каналы 4 & 89 - 8
#
# Каналы 89 & 4 - 12
#
# Каналы 4 & 91 - 12
#
# Каналы 4 & 92 - 15
#
# Каналы 92 & 4 - 7
#
# Каналы 93 & 4 - 11
#
# Каналы 4 & 94 - 12
#
# Каналы 4 & 95 - 11
#
# Каналы 4 & 96 - 8
#
# Каналы 98 & 4 - 9
#
# Каналы 5 & 7 - 14
#
# Каналы 5 & 8 - 12
#
# Каналы 5 & 11 - 17
#
# Каналы 11 & 5 - 10
#
# Каналы 5 & 12 - 16
#
# Каналы 13 & 5 - 10
#
# Каналы 14 & 5 - 13
#
# Каналы 15 & 5 - 9
#
# Каналы 16 & 5 - 12
#
# Каналы 5 & 17 - 7
#
# Каналы 17 & 5 - 11
#
# Каналы 19 & 5 - 9
#
# Каналы 5 & 21 - 10
#
# Каналы 21 & 5 - 10
#
# Каналы 5 & 23 - 14
#
# Каналы 23 & 5 - 10
#
# Каналы 5 & 24 - 10
#
# Каналы 25 & 5 - 11
#
# Каналы 5 & 26 - 6
#
# Каналы 5 & 27 - 12
#
# Каналы 27 & 5 - 11
#
# Каналы 5 & 28 - 10
#
# Каналы 5 & 29 - 7
#
# Каналы 29 & 5 - 9
#
# Каналы 5 & 30 - 7
#
# Каналы 5 & 32 - 7
#
# Каналы 32 & 5 - 3
#
# Каналы 35 & 5 - 8
#
# Каналы 36 & 5 - 5
#
# Каналы 5 & 37 - 11
#
# Каналы 39 & 5 - 9
#
# Каналы 5 & 41 - 13
#
# Каналы 41 & 5 - 7
#
# Каналы 5 & 42 - 10
#
# Каналы 44 & 5 - 10
#
# Каналы 45 & 5 - 8
#
# Каналы 5 & 46 - 9
#
# Каналы 46 & 5 - 11
#
# Каналы 5 & 47 - 11
#
# Каналы 47 & 5 - 7
#
# Каналы 5 & 48 - 9
#
# Каналы 48 & 5 - 8
#
# Каналы 5 & 49 - 9
#
# Каналы 49 & 5 - 10
#
# Каналы 50 & 5 - 14
#
# Каналы 5 & 51 - 11
#
# Каналы 51 & 5 - 12
#
# Каналы 52 & 5 - 10
#
# Каналы 56 & 5 - 6
#
# Каналы 5 & 57 - 13
#
# Каналы 58 & 5 - 9
#
# Каналы 5 & 59 - 14
#
# Каналы 59 & 5 - 11
#
# Каналы 61 & 5 - 13
#
# Каналы 5 & 62 - 15
#
# Каналы 62 & 5 - 9
#
# Каналы 5 & 63 - 8
#
# Каналы 5 & 64 - 17
#
# Каналы 64 & 5 - 8
#
# Каналы 65 & 5 - 6
#
# Каналы 5 & 66 - 9
#
# Каналы 66 & 5 - 8
#
# Каналы 68 & 5 - 6
#
# Каналы 5 & 69 - 9
#
# Каналы 69 & 5 - 13
#
# Каналы 5 & 70 - 14
#
# Каналы 70 & 5 - 13
#
# Каналы 5 & 71 - 14
#
# Каналы 73 & 5 - 8
#
# Каналы 74 & 5 - 8
#
# Каналы 76 & 5 - 9
#
# Каналы 5 & 77 - 18
#
# Каналы 77 & 5 - 12
#
# Каналы 5 & 78 - 10
#
# Каналы 78 & 5 - 11
#
# Каналы 5 & 80 - 12
#
# Каналы 80 & 5 - 6
#
# Каналы 81 & 5 - 10
#
# Каналы 5 & 82 - 7
#
# Каналы 82 & 5 - 10
#
# Каналы 5 & 83 - 9
#
# Каналы 83 & 5 - 7
#
# Каналы 84 & 5 - 15
#
# Каналы 5 & 86 - 8
#
# Каналы 5 & 87 - 12
#
# Каналы 87 & 5 - 13
#
# Каналы 5 & 88 - 7
#
# Каналы 5 & 89 - 11
#
# Каналы 5 & 90 - 11
#
# Каналы 90 & 5 - 12
#
# Каналы 91 & 5 - 7
#
# Каналы 5 & 92 - 12
#
# Каналы 5 & 93 - 12
#
# Каналы 93 & 5 - 11
#
# Каналы 5 & 94 - 10
#
# Каналы 94 & 5 - 9
#
# Каналы 95 & 5 - 14
#
# Каналы 5 & 96 - 7
#
# Каналы 5 & 97 - 7
#
# Каналы 97 & 5 - 7
#
# Каналы 5 & 98 - 7
#
# Каналы 6 & 7 - 4
#
# Каналы 8 & 6 - 10
#
# Каналы 6 & 9 - 10
#
# Каналы 9 & 6 - 18
#
# Каналы 6 & 10 - 6
#
# Каналы 10 & 6 - 10
#
# Каналы 11 & 6 - 9
#
# Каналы 6 & 12 - 7
#
# Каналы 6 & 14 - 6
#
# Каналы 16 & 6 - 5
#
# Каналы 6 & 17 - 11
#
# Каналы 6 & 19 - 17
#
# Каналы 19 & 6 - 11
#
# Каналы 6 & 20 - 11
#
# Каналы 21 & 6 - 6
#
# Каналы 22 & 6 - 10
#
# Каналы 6 & 23 - 12
#
# Каналы 23 & 6 - 7
#
# Каналы 6 & 24 - 3
#
# Каналы 6 & 25 - 4
#
# Каналы 6 & 26 - 5
#
# Каналы 26 & 6 - 7
#
# Каналы 6 & 27 - 8
#
# Каналы 6 & 30 - 17
#
# Каналы 6 & 31 - 13
#
# Каналы 31 & 6 - 16
#
# Каналы 34 & 6 - 10
#
# Каналы 6 & 35 - 11
#
# Каналы 35 & 6 - 15
#
# Каналы 6 & 36 - 11
#
# Каналы 6 & 37 - 9
#
# Каналы 37 & 6 - 9
#
# Каналы 6 & 38 - 11
#
# Каналы 38 & 6 - 16
#
# Каналы 40 & 6 - 12
#
# Каналы 6 & 41 - 7
#
# Каналы 42 & 6 - 12
#
# Каналы 43 & 6 - 10
#
# Каналы 6 & 44 - 11
#
# Каналы 6 & 45 - 14
#
# Каналы 45 & 6 - 10
#
# Каналы 6 & 47 - 17
#
# Каналы 48 & 6 - 7
#
# Каналы 6 & 49 - 12
#
# Каналы 49 & 6 - 9
#
# Каналы 6 & 50 - 11
#
# Каналы 51 & 6 - 13
#
# Каналы 6 & 53 - 6
#
# Каналы 53 & 6 - 15
#
# Каналы 54 & 6 - 10
#
# Каналы 55 & 6 - 11
#
# Каналы 56 & 6 - 10
#
# Каналы 6 & 57 - 7
#
# Каналы 57 & 6 - 8
#
# Каналы 58 & 6 - 15
#
# Каналы 59 & 6 - 11
#
# Каналы 6 & 60 - 9
#
# Каналы 60 & 6 - 12
#
# Каналы 6 & 61 - 9
#
# Каналы 6 & 62 - 10
#
# Каналы 6 & 64 - 8
#
# Каналы 64 & 6 - 11
#
# Каналы 6 & 65 - 12
#
# Каналы 6 & 66 - 10
#
# Каналы 66 & 6 - 5
#
# Каналы 6 & 68 - 7
#
# Каналы 68 & 6 - 9
#
# Каналы 6 & 69 - 9
#
# Каналы 69 & 6 - 11
#
# Каналы 70 & 6 - 11
#
# Каналы 72 & 6 - 7
#
# Каналы 6 & 73 - 10
#
# Каналы 74 & 6 - 4
#
# Каналы 6 & 75 - 11
#
# Каналы 6 & 76 - 13
#
# Каналы 77 & 6 - 6
#
# Каналы 78 & 6 - 10
#
# Каналы 79 & 6 - 11
#
# Каналы 6 & 81 - 9
#
# Каналы 81 & 6 - 12
#
# Каналы 6 & 82 - 8
#
# Каналы 83 & 6 - 10
#
# Каналы 6 & 84 - 10
#
# Каналы 6 & 85 - 11
#
# Каналы 85 & 6 - 14
#
# Каналы 86 & 6 - 13
#
# Каналы 6 & 87 - 9
#
# Каналы 6 & 88 - 11
#
# Каналы 88 & 6 - 10
#
# Каналы 6 & 89 - 9
#
# Каналы 89 & 6 - 5
#
# Каналы 6 & 90 - 9
#
# Каналы 92 & 6 - 10
#
# Каналы 93 & 6 - 11
#
# Каналы 6 & 94 - 10
#
# Каналы 94 & 6 - 15
#
# Каналы 6 & 95 - 11
#
# Каналы 95 & 6 - 12
#
# Каналы 97 & 6 - 11
#
# Каналы 6 & 98 - 9
#
# Каналы 7 & 8 - 5
#
# Каналы 7 & 9 - 18
#
# Каналы 10 & 7 - 10
#
# Каналы 12 & 7 - 11
#
# Каналы 13 & 7 - 10
#
# Каналы 14 & 7 - 16
#
# Каналы 7 & 15 - 11
#
# Каналы 15 & 7 - 13
#
# Каналы 19 & 7 - 10
#
# Каналы 21 & 7 - 12
#
# Каналы 7 & 22 - 11
#
# Каналы 22 & 7 - 12
#
# Каналы 7 & 23 - 10
#
# Каналы 7 & 24 - 10
#
# Каналы 25 & 7 - 4
#
# Каналы 7 & 26 - 7
#
# Каналы 26 & 7 - 9
#
# Каналы 7 & 28 - 6
#
# Каналы 28 & 7 - 17
#
# Каналы 7 & 29 - 6
#
# Каналы 30 & 7 - 14
#
# Каналы 32 & 7 - 10
#
# Каналы 7 & 34 - 10
#
# Каналы 34 & 7 - 6
#
# Каналы 7 & 35 - 8
#
# Каналы 35 & 7 - 10
#
# Каналы 36 & 7 - 10
#
# Каналы 7 & 37 - 10
#
# Каналы 38 & 7 - 12
#
# Каналы 7 & 39 - 5
#
# Каналы 39 & 7 - 8
#
# Каналы 7 & 40 - 9
#
# Каналы 40 & 7 - 10
#
# Каналы 7 & 42 - 7
#
# Каналы 43 & 7 - 8
#
# Каналы 7 & 44 - 13
#
# Каналы 44 & 7 - 6
#
# Каналы 45 & 7 - 10
#
# Каналы 7 & 46 - 9
#
# Каналы 46 & 7 - 8
#
# Каналы 7 & 48 - 8
#
# Каналы 48 & 7 - 11
#
# Каналы 7 & 49 - 8
#
# Каналы 50 & 7 - 10
#
# Каналы 7 & 52 - 7
#
# Каналы 52 & 7 - 10
#
# Каналы 53 & 7 - 13
#
# Каналы 7 & 54 - 11
#
# Каналы 54 & 7 - 7
#
# Каналы 55 & 7 - 5
#
# Каналы 7 & 56 - 12
#
# Каналы 57 & 7 - 6
#
# Каналы 59 & 7 - 10
#
# Каналы 60 & 7 - 14
#
# Каналы 61 & 7 - 10
#
# Каналы 7 & 63 - 17
#
# Каналы 63 & 7 - 13
#
# Каналы 7 & 64 - 10
#
# Каналы 7 & 65 - 4
#
# Каналы 65 & 7 - 6
#
# Каналы 7 & 66 - 9
#
# Каналы 66 & 7 - 14
#
# Каналы 67 & 7 - 6
#
# Каналы 68 & 7 - 14
#
# Каналы 7 & 69 - 12
#
# Каналы 7 & 70 - 11
#
# Каналы 7 & 71 - 8
#
# Каналы 72 & 7 - 6
#
# Каналы 7 & 73 - 11
#
# Каналы 73 & 7 - 7
#
# Каналы 75 & 7 - 12
#
# Каналы 76 & 7 - 8
#
# Каналы 7 & 77 - 4
#
# Каналы 7 & 78 - 10
#
# Каналы 78 & 7 - 13
#
# Каналы 7 & 80 - 9
#
# Каналы 80 & 7 - 10
#
# Каналы 7 & 81 - 5
#
# Каналы 7 & 83 - 9
#
# Каналы 83 & 7 - 8
#
# Каналы 7 & 84 - 10
#
# Каналы 84 & 7 - 8
#
# Каналы 7 & 86 - 10
#
# Каналы 86 & 7 - 11
#
# Каналы 88 & 7 - 12
#
# Каналы 89 & 7 - 11
#
# Каналы 91 & 7 - 9
#
# Каналы 7 & 92 - 5
#
# Каналы 92 & 7 - 10
#
# Каналы 7 & 93 - 13
#
# Каналы 7 & 96 - 10
#
# Каналы 7 & 97 - 7
#
# Каналы 97 & 7 - 10
#
# Каналы 7 & 98 - 10
#
# Каналы 99 & 7 - 10
#
# Каналы 8 & 9 - 10
#
# Каналы 10 & 8 - 10
#
# Каналы 11 & 8 - 13
#
# Каналы 8 & 12 - 5
#
# Каналы 8 & 13 - 12
#
# Каналы 8 & 14 - 5
#
# Каналы 14 & 8 - 9
#
# Каналы 8 & 15 - 11
#
# Каналы 15 & 8 - 5
#
# Каналы 8 & 17 - 10
#
# Каналы 20 & 8 - 8
#
# Каналы 8 & 23 - 7
#
# Каналы 23 & 8 - 10
#
# Каналы 8 & 24 - 11
#
# Каналы 8 & 25 - 9
#
# Каналы 8 & 27 - 7
#
# Каналы 27 & 8 - 9
#
# Каналы 28 & 8 - 15
#
# Каналы 8 & 29 - 9
#
# Каналы 29 & 8 - 11
#
# Каналы 8 & 30 - 13
#
# Каналы 31 & 8 - 7
#
# Каналы 8 & 34 - 8
#
# Каналы 34 & 8 - 12
#
# Каналы 35 & 8 - 13
#
# Каналы 8 & 38 - 10
#
# Каналы 41 & 8 - 9
#
# Каналы 43 & 8 - 8
#
# Каналы 8 & 45 - 7
#
# Каналы 45 & 8 - 15
#
# Каналы 8 & 46 - 9
#
# Каналы 8 & 49 - 5
#
# Каналы 49 & 8 - 15
#
# Каналы 50 & 8 - 10
#
# Каналы 8 & 51 - 7
#
# Каналы 8 & 54 - 8
#
# Каналы 8 & 58 - 9
#
# Каналы 8 & 59 - 10
#
# Каналы 59 & 8 - 7
#
# Каналы 8 & 60 - 7
#
# Каналы 8 & 61 - 10
#
# Каналы 62 & 8 - 7
#
# Каналы 8 & 63 - 15
#
# Каналы 65 & 8 - 9
#
# Каналы 8 & 66 - 9
#
# Каналы 66 & 8 - 8
#
# Каналы 8 & 67 - 4
#
# Каналы 67 & 8 - 10
#
# Каналы 68 & 8 - 14
#
# Каналы 69 & 8 - 17
#
# Каналы 70 & 8 - 9
#
# Каналы 8 & 71 - 8
#
# Каналы 71 & 8 - 12
#
# Каналы 8 & 73 - 15
#
# Каналы 73 & 8 - 15
#
# Каналы 8 & 74 - 7
#
# Каналы 74 & 8 - 9
#
# Каналы 8 & 75 - 8
#
# Каналы 8 & 76 - 8
#
# Каналы 78 & 8 - 6
#
# Каналы 8 & 79 - 13
#
# Каналы 8 & 80 - 11
#
# Каналы 80 & 8 - 11
#
# Каналы 8 & 81 - 7
#
# Каналы 81 & 8 - 7
#
# Каналы 82 & 8 - 9
#
# Каналы 8 & 83 - 17
#
# Каналы 84 & 8 - 8
#
# Каналы 86 & 8 - 13
#
# Каналы 8 & 88 - 12
#
# Каналы 88 & 8 - 8
#
# Каналы 89 & 8 - 10
#
# Каналы 8 & 92 - 10
#
# Каналы 92 & 8 - 8
#
# Каналы 8 & 95 - 7
#
# Каналы 95 & 8 - 4
#
# Каналы 8 & 98 - 6
#
# Каналы 98 & 8 - 12
#
# Каналы 8 & 99 - 6
#
# Каналы 9 & 10 - 12
#
# Каналы 10 & 9 - 9
#
# Каналы 9 & 11 - 6
#
# Каналы 9 & 12 - 11
#
# Каналы 12 & 9 - 13
#
# Каналы 9 & 13 - 13
#
# Каналы 14 & 9 - 7
#
# Каналы 17 & 9 - 14
#
# Каналы 18 & 9 - 13
#
# Каналы 9 & 19 - 9
#
# Каналы 19 & 9 - 9
#
# Каналы 20 & 9 - 12
#
# Каналы 9 & 21 - 10
#
# Каналы 21 & 9 - 4
#
# Каналы 9 & 22 - 11
#
# Каналы 22 & 9 - 12
#
# Каналы 23 & 9 - 12
#
# Каналы 9 & 25 - 8
#
# Каналы 25 & 9 - 9
#
# Каналы 26 & 9 - 7
#
# Каналы 9 & 27 - 5
#
# Каналы 9 & 29 - 12
#
# Каналы 29 & 9 - 7
#
# Каналы 31 & 9 - 6
#
# Каналы 9 & 32 - 8
#
# Каналы 9 & 33 - 14
#
# Каналы 35 & 9 - 13
#
# Каналы 9 & 37 - 7
#
# Каналы 37 & 9 - 6
#
# Каналы 38 & 9 - 12
#
# Каналы 9 & 39 - 5
#
# Каналы 9 & 40 - 9
#
# Каналы 41 & 9 - 9
#
# Каналы 9 & 42 - 11
#
# Каналы 9 & 43 - 16
#
# Каналы 9 & 44 - 7
#
# Каналы 45 & 9 - 8
#
# Каналы 46 & 9 - 14
#
# Каналы 9 & 47 - 13
#
# Каналы 9 & 48 - 16
#
# Каналы 9 & 49 - 12
#
# Каналы 50 & 9 - 15
#
# Каналы 9 & 52 - 8
#
# Каналы 52 & 9 - 15
#
# Каналы 9 & 53 - 6
#
# Каналы 54 & 9 - 16
#
# Каналы 9 & 55 - 13
#
# Каналы 56 & 9 - 10
#
# Каналы 57 & 9 - 8
#
# Каналы 9 & 58 - 10
#
# Каналы 58 & 9 - 7
#
# Каналы 9 & 59 - 9
#
# Каналы 59 & 9 - 12
#
# Каналы 9 & 60 - 11
#
# Каналы 9 & 62 - 9
#
# Каналы 62 & 9 - 9
#
# Каналы 9 & 63 - 8
#
# Каналы 64 & 9 - 13
#
# Каналы 9 & 65 - 10
#
# Каналы 66 & 9 - 8
#
# Каналы 9 & 68 - 14
#
# Каналы 9 & 70 - 6
#
# Каналы 9 & 71 - 10
#
# Каналы 9 & 73 - 6
#
# Каналы 9 & 74 - 11
#
# Каналы 74 & 9 - 11
#
# Каналы 9 & 75 - 15
#
# Каналы 76 & 9 - 10
#
# Каналы 77 & 9 - 10
#
# Каналы 9 & 79 - 15
#
# Каналы 79 & 9 - 9
#
# Каналы 80 & 9 - 13
#
# Каналы 9 & 81 - 9
#
# Каналы 83 & 9 - 12
#
# Каналы 9 & 84 - 12
#
# Каналы 9 & 85 - 14
#
# Каналы 85 & 9 - 8
#
# Каналы 86 & 9 - 7
#
# Каналы 9 & 87 - 10
#
# Каналы 9 & 88 - 9
#
# Каналы 88 & 9 - 8
#
# Каналы 89 & 9 - 9
#
# Каналы 90 & 9 - 16
#
# Каналы 91 & 9 - 10
#
# Каналы 92 & 9 - 9
#
# Каналы 9 & 94 - 11
#
# Каналы 94 & 9 - 12
#
# Каналы 9 & 95 - 11
#
# Каналы 96 & 9 - 12
#
# Каналы 97 & 9 - 17
#
# Каналы 9 & 98 - 13
#
# Каналы 10 & 11 - 6
#
# Каналы 10 & 13 - 12
#
# Каналы 10 & 14 - 12
#
# Каналы 14 & 10 - 6
#
# Каналы 10 & 15 - 3
#
# Каналы 15 & 10 - 8
#
# Каналы 10 & 17 - 14
#
# Каналы 17 & 10 - 14
#
# Каналы 18 & 10 - 11
#
# Каналы 10 & 19 - 8
#
# Каналы 20 & 10 - 13
#
# Каналы 10 & 21 - 7
#
# Каналы 21 & 10 - 10
#
# Каналы 22 & 10 - 10
#
# Каналы 10 & 23 - 9
#
# Каналы 10 & 24 - 11
#
# Каналы 24 & 10 - 9
#
# Каналы 10 & 25 - 3
#
# Каналы 25 & 10 - 15
#
# Каналы 10 & 27 - 12
#
# Каналы 10 & 28 - 8
#
# Каналы 28 & 10 - 9
#
# Каналы 29 & 10 - 12
#
# Каналы 30 & 10 - 7
#
# Каналы 31 & 10 - 10
#
# Каналы 10 & 32 - 15
#
# Каналы 32 & 10 - 17
#
# Каналы 10 & 33 - 12
#
# Каналы 10 & 34 - 11
#
# Каналы 10 & 35 - 12
#
# Каналы 35 & 10 - 11
#
# Каналы 10 & 36 - 7
#
# Каналы 36 & 10 - 12
#
# Каналы 10 & 37 - 13
#
# Каналы 10 & 38 - 10
#
# Каналы 10 & 39 - 10
#
# Каналы 39 & 10 - 6
#
# Каналы 40 & 10 - 9
#
# Каналы 41 & 10 - 7
#
# Каналы 43 & 10 - 10
#
# Каналы 45 & 10 - 12
#
# Каналы 46 & 10 - 13
#
# Каналы 10 & 47 - 9
#
# Каналы 48 & 10 - 14
#
# Каналы 50 & 10 - 9
#
# Каналы 10 & 51 - 5
#
# Каналы 52 & 10 - 14
#
# Каналы 10 & 53 - 6
#
# Каналы 53 & 10 - 9
#
# Каналы 10 & 54 - 8
#
# Каналы 54 & 10 - 8
#
# Каналы 10 & 55 - 7
#
# Каналы 55 & 10 - 9
#
# Каналы 58 & 10 - 19
#
# Каналы 10 & 59 - 11
#
# Каналы 59 & 10 - 14
#
# Каналы 10 & 60 - 14
#
# Каналы 60 & 10 - 8
#
# Каналы 61 & 10 - 11
#
# Каналы 10 & 63 - 10
#
# Каналы 63 & 10 - 11
#
# Каналы 65 & 10 - 12
#
# Каналы 10 & 66 - 17
#
# Каналы 66 & 10 - 6
#
# Каналы 10 & 67 - 6
#
# Каналы 67 & 10 - 8
#
# Каналы 68 & 10 - 15
#
# Каналы 70 & 10 - 6
#
# Каналы 10 & 71 - 14
#
# Каналы 71 & 10 - 17
#
# Каналы 10 & 74 - 9
#
# Каналы 75 & 10 - 11
#
# Каналы 10 & 76 - 10
#
# Каналы 76 & 10 - 9
#
# Каналы 77 & 10 - 11
#
# Каналы 79 & 10 - 14
#
# Каналы 10 & 80 - 10
#
# Каналы 80 & 10 - 8
#
# Каналы 10 & 81 - 10
#
# Каналы 10 & 82 - 10
#
# Каналы 10 & 83 - 11
#
# Каналы 83 & 10 - 11
#
# Каналы 10 & 85 - 7
#
# Каналы 86 & 10 - 13
#
# Каналы 10 & 88 - 8
#
# Каналы 91 & 10 - 8
#
# Каналы 10 & 92 - 5
#
# Каналы 92 & 10 - 11
#
# Каналы 93 & 10 - 9
#
# Каналы 10 & 96 - 9
#
# Каналы 96 & 10 - 10
#
# Каналы 10 & 97 - 7
#
# Каналы 97 & 10 - 15
#
# Каналы 10 & 98 - 5
#
# Каналы 98 & 10 - 2
#
# Каналы 99 & 10 - 15
#
# Каналы 11 & 12 - 8
#
# Каналы 12 & 11 - 9
#
# Каналы 11 & 13 - 10
#
# Каналы 13 & 11 - 6
#
# Каналы 14 & 11 - 13
#
# Каналы 11 & 15 - 11
#
# Каналы 15 & 11 - 7
#
# Каналы 11 & 16 - 7
#
# Каналы 18 & 11 - 9
#
# Каналы 19 & 11 - 9
#
# Каналы 11 & 20 - 7
#
# Каналы 11 & 21 - 5
#
# Каналы 21 & 11 - 10
#
# Каналы 22 & 11 - 7
#
# Каналы 11 & 23 - 18
#
# Каналы 11 & 24 - 7
#
# Каналы 24 & 11 - 19
#
# Каналы 11 & 25 - 12
#
# Каналы 26 & 11 - 14
#
# Каналы 11 & 27 - 7
#
# Каналы 27 & 11 - 10
#
# Каналы 11 & 30 - 15
#
# Каналы 30 & 11 - 9
#
# Каналы 11 & 31 - 6
#
# Каналы 31 & 11 - 11
#
# Каналы 34 & 11 - 8
#
# Каналы 11 & 36 - 13
#
# Каналы 36 & 11 - 14
#
# Каналы 11 & 37 - 8
#
# Каналы 38 & 11 - 12
#
# Каналы 11 & 39 - 13
#
# Каналы 11 & 40 - 12
#
# Каналы 11 & 41 - 11
#
# Каналы 41 & 11 - 9
#
# Каналы 11 & 42 - 11
#
# Каналы 42 & 11 - 13
#
# Каналы 11 & 44 - 6
#
# Каналы 11 & 45 - 12
#
# Каналы 45 & 11 - 14
#
# Каналы 11 & 46 - 9
#
# Каналы 47 & 11 - 9
#
# Каналы 11 & 48 - 9
#
# Каналы 48 & 11 - 5
#
# Каналы 11 & 49 - 7
#
# Каналы 11 & 50 - 11
#
# Каналы 50 & 11 - 7
#
# Каналы 11 & 52 - 2
#
# Каналы 52 & 11 - 9
#
# Каналы 53 & 11 - 9
#
# Каналы 11 & 54 - 15
#
# Каналы 55 & 11 - 10
#
# Каналы 11 & 58 - 8
#
# Каналы 59 & 11 - 8
#
# Каналы 60 & 11 - 10
#
# Каналы 11 & 61 - 14
#
# Каналы 11 & 63 - 8
#
# Каналы 63 & 11 - 10
#
# Каналы 11 & 65 - 10
#
# Каналы 11 & 66 - 7
#
# Каналы 66 & 11 - 10
#
# Каналы 11 & 68 - 14
#
# Каналы 68 & 11 - 9
#
# Каналы 69 & 11 - 12
#
# Каналы 11 & 71 - 12
#
# Каналы 71 & 11 - 18
#
# Каналы 11 & 72 - 10
#
# Каналы 11 & 73 - 10
#
# Каналы 11 & 74 - 11
#
# Каналы 74 & 11 - 12
#
# Каналы 11 & 75 - 14
#
# Каналы 76 & 11 - 12
#
# Каналы 78 & 11 - 7
#
# Каналы 11 & 79 - 6
#
# Каналы 80 & 11 - 7
#
# Каналы 81 & 11 - 8
#
# Каналы 82 & 11 - 5
#
# Каналы 85 & 11 - 6
#
# Каналы 86 & 11 - 10
#
# Каналы 88 & 11 - 10
#
# Каналы 89 & 11 - 8
#
# Каналы 11 & 92 - 13
#
# Каналы 11 & 93 - 6
#
# Каналы 93 & 11 - 10
#
# Каналы 94 & 11 - 11
#
# Каналы 11 & 97 - 12
#
# Каналы 97 & 11 - 11
#
# Каналы 98 & 11 - 15
#
# Каналы 99 & 11 - 9
#
# Каналы 13 & 12 - 10
#
# Каналы 12 & 14 - 11
#
# Каналы 12 & 15 - 14
#
# Каналы 15 & 12 - 13
#
# Каналы 12 & 16 - 16
#
# Каналы 12 & 17 - 8
#
# Каналы 12 & 18 - 9
#
# Каналы 12 & 20 - 9
#
# Каналы 20 & 12 - 13
#
# Каналы 12 & 21 - 11
#
# Каналы 12 & 22 - 15
#
# Каналы 12 & 23 - 12
#
# Каналы 12 & 24 - 10
#
# Каналы 12 & 25 - 11
#
# Каналы 25 & 12 - 13
#
# Каналы 12 & 26 - 15
#
# Каналы 26 & 12 - 11
#
# Каналы 27 & 12 - 16
#
# Каналы 12 & 28 - 11
#
# Каналы 28 & 12 - 10
#
# Каналы 12 & 29 - 9
#
# Каналы 29 & 12 - 11
#
# Каналы 12 & 31 - 8
#
# Каналы 31 & 12 - 12
#
# Каналы 12 & 32 - 8
#
# Каналы 32 & 12 - 11
#
# Каналы 33 & 12 - 4
#
# Каналы 12 & 37 - 8
#
# Каналы 12 & 39 - 11
#
# Каналы 12 & 40 - 7
#
# Каналы 40 & 12 - 8
#
# Каналы 41 & 12 - 10
#
# Каналы 12 & 42 - 12
#
# Каналы 12 & 43 - 13
#
# Каналы 12 & 45 - 9
#
# Каналы 46 & 12 - 15
#
# Каналы 47 & 12 - 11
#
# Каналы 12 & 48 - 14
#
# Каналы 49 & 12 - 11
#
# Каналы 12 & 51 - 6
#
# Каналы 12 & 53 - 14
#
# Каналы 53 & 12 - 15
#
# Каналы 12 & 55 - 8
#
# Каналы 55 & 12 - 10
#
# Каналы 12 & 56 - 11
#
# Каналы 12 & 58 - 10
#
# Каналы 12 & 59 - 8
#
# Каналы 12 & 62 - 4
#
# Каналы 62 & 12 - 5
#
# Каналы 12 & 64 - 8
#
# Каналы 64 & 12 - 9
#
# Каналы 65 & 12 - 3
#
# Каналы 12 & 66 - 8
#
# Каналы 12 & 67 - 13
#
# Каналы 12 & 68 - 6
#
# Каналы 12 & 69 - 9
#
# Каналы 12 & 71 - 11
#
# Каналы 71 & 12 - 12
#
# Каналы 12 & 72 - 15
#
# Каналы 12 & 73 - 6
#
# Каналы 73 & 12 - 9
#
# Каналы 74 & 12 - 12
#
# Каналы 12 & 75 - 7
#
# Каналы 75 & 12 - 5
#
# Каналы 12 & 76 - 9
#
# Каналы 76 & 12 - 11
#
# Каналы 77 & 12 - 10
#
# Каналы 12 & 78 - 14
#
# Каналы 79 & 12 - 10
#
# Каналы 12 & 80 - 7
#
# Каналы 80 & 12 - 7
#
# Каналы 81 & 12 - 11
#
# Каналы 12 & 82 - 12
#
# Каналы 82 & 12 - 17
#
# Каналы 12 & 83 - 8
#
# Каналы 12 & 84 - 13
#
# Каналы 86 & 12 - 10
#
# Каналы 12 & 87 - 10
#
# Каналы 87 & 12 - 13
#
# Каналы 12 & 88 - 8
#
# Каналы 12 & 89 - 11
#
# Каналы 89 & 12 - 12
#
# Каналы 12 & 90 - 11
#
# Каналы 91 & 12 - 14
#
# Каналы 93 & 12 - 11
#
# Каналы 12 & 94 - 6
#
# Каналы 95 & 12 - 13
#
# Каналы 98 & 12 - 9
#
# Каналы 12 & 99 - 15
#
# Каналы 13 & 14 - 7
#
# Каналы 14 & 13 - 7
#
# Каналы 13 & 19 - 8
#
# Каналы 20 & 13 - 9
#
# Каналы 22 & 13 - 14
#
# Каналы 23 & 13 - 11
#
# Каналы 24 & 13 - 8
#
# Каналы 25 & 13 - 8
#
# Каналы 13 & 27 - 10
#
# Каналы 27 & 13 - 4
#
# Каналы 13 & 28 - 10
#
# Каналы 30 & 13 - 9
#
# Каналы 13 & 32 - 12
#
# Каналы 35 & 13 - 11
#
# Каналы 13 & 36 - 19
#
# Каналы 38 & 13 - 10
#
# Каналы 41 & 13 - 9
#
# Каналы 42 & 13 - 9
#
# Каналы 13 & 43 - 8
#
# Каналы 13 & 44 - 10
#
# Каналы 44 & 13 - 8
#
# Каналы 45 & 13 - 15
#
# Каналы 13 & 46 - 9
#
# Каналы 46 & 13 - 12
#
# Каналы 13 & 47 - 11
#
# Каналы 47 & 13 - 11
#
# Каналы 49 & 13 - 13
#
# Каналы 50 & 13 - 7
#
# Каналы 13 & 51 - 9
#
# Каналы 13 & 52 - 2
#
# Каналы 53 & 13 - 7
#
# Каналы 54 & 13 - 13
#
# Каналы 13 & 56 - 8
#
# Каналы 56 & 13 - 10
#
# Каналы 13 & 58 - 11
#
# Каналы 58 & 13 - 10
#
# Каналы 59 & 13 - 8
#
# Каналы 13 & 60 - 8
#
# Каналы 60 & 13 - 8
#
# Каналы 61 & 13 - 11
#
# Каналы 13 & 62 - 12
#
# Каналы 64 & 13 - 13
#
# Каналы 13 & 66 - 14
#
# Каналы 13 & 67 - 6
#
# Каналы 68 & 13 - 11
#
# Каналы 13 & 69 - 6
#
# Каналы 69 & 13 - 7
#
# Каналы 13 & 70 - 8
#
# Каналы 70 & 13 - 13
#
# Каналы 72 & 13 - 8
#
# Каналы 13 & 73 - 5
#
# Каналы 74 & 13 - 7
#
# Каналы 75 & 13 - 10
#
# Каналы 76 & 13 - 7
#
# Каналы 13 & 77 - 11
#
# Каналы 77 & 13 - 12
#
# Каналы 13 & 78 - 8
#
# Каналы 78 & 13 - 6
#
# Каналы 13 & 81 - 17
#
# Каналы 13 & 82 - 8
#
# Каналы 83 & 13 - 6
#
# Каналы 13 & 84 - 10
#
# Каналы 84 & 13 - 8
#
# Каналы 13 & 85 - 7
#
# Каналы 85 & 13 - 12
#
# Каналы 13 & 86 - 12
#
# Каналы 13 & 87 - 10
#
# Каналы 13 & 88 - 10
#
# Каналы 88 & 13 - 8
#
# Каналы 13 & 89 - 11
#
# Каналы 89 & 13 - 6
#
# Каналы 13 & 91 - 15
#
# Каналы 91 & 13 - 9
#
# Каналы 13 & 93 - 10
#
# Каналы 93 & 13 - 10
#
# Каналы 13 & 94 - 13
#
# Каналы 94 & 13 - 8
#
# Каналы 13 & 95 - 8
#
# Каналы 13 & 96 - 12
#
# Каналы 13 & 97 - 8
#
# Каналы 97 & 13 - 10
#
# Каналы 13 & 98 - 11
#
# Каналы 98 & 13 - 12
#
# Каналы 99 & 13 - 15
#
# Каналы 14 & 15 - 15
#
# Каналы 17 & 14 - 11
#
# Каналы 19 & 14 - 10
#
# Каналы 14 & 20 - 6
#
# Каналы 20 & 14 - 10
#
# Каналы 14 & 21 - 11
#
# Каналы 14 & 23 - 11
#
# Каналы 23 & 14 - 10
#
# Каналы 24 & 14 - 10
#
# Каналы 14 & 26 - 4
#
# Каналы 26 & 14 - 11
#
# Каналы 14 & 27 - 9
#
# Каналы 14 & 28 - 8
#
# Каналы 14 & 29 - 11
#
# Каналы 29 & 14 - 10
#
# Каналы 30 & 14 - 9
#
# Каналы 31 & 14 - 8
#
# Каналы 14 & 32 - 8
#
# Каналы 32 & 14 - 14
#
# Каналы 14 & 36 - 16
#
# Каналы 14 & 37 - 8
#
# Каналы 37 & 14 - 14
#
# Каналы 14 & 38 - 7
#
# Каналы 14 & 39 - 7
#
# Каналы 14 & 41 - 5
#
# Каналы 41 & 14 - 11
#
# Каналы 42 & 14 - 6
#
# Каналы 14 & 44 - 11
#
# Каналы 44 & 14 - 9
#
# Каналы 14 & 45 - 7
#
# Каналы 46 & 14 - 7
#
# Каналы 14 & 48 - 7
#
# Каналы 48 & 14 - 8
#
# Каналы 14 & 49 - 7
#
# Каналы 49 & 14 - 9
#
# Каналы 14 & 50 - 5
#
# Каналы 14 & 51 - 7
#
# Каналы 14 & 53 - 9
#
# Каналы 53 & 14 - 7
#
# Каналы 14 & 54 - 11
#
# Каналы 54 & 14 - 7
#
# Каналы 55 & 14 - 14
#
# Каналы 56 & 14 - 10
#
# Каналы 14 & 57 - 9
#
# Каналы 14 & 58 - 10
#
# Каналы 58 & 14 - 10
#
# Каналы 14 & 59 - 16
#
# Каналы 59 & 14 - 10
#
# Каналы 14 & 61 - 11
#
# Каналы 61 & 14 - 7
#
# Каналы 14 & 62 - 9
#
# Каналы 62 & 14 - 9
#
# Каналы 63 & 14 - 6
#
# Каналы 64 & 14 - 8
#
# Каналы 14 & 65 - 10
#
# Каналы 65 & 14 - 9
#
# Каналы 66 & 14 - 9
#
# Каналы 68 & 14 - 14
#
# Каналы 14 & 69 - 4
#
# Каналы 70 & 14 - 13
#
# Каналы 14 & 71 - 8
#
# Каналы 71 & 14 - 13
#
# Каналы 14 & 72 - 15
#
# Каналы 73 & 14 - 12
#
# Каналы 14 & 76 - 2
#
# Каналы 14 & 77 - 12
#
# Каналы 77 & 14 - 6
#
# Каналы 78 & 14 - 7
#
# Каналы 14 & 79 - 9
#
# Каналы 14 & 80 - 11
#
# Каналы 80 & 14 - 8
#
# Каналы 81 & 14 - 6
#
# Каналы 14 & 84 - 12
#
# Каналы 84 & 14 - 11
#
# Каналы 86 & 14 - 12
#
# Каналы 14 & 87 - 6
#
# Каналы 87 & 14 - 9
#
# Каналы 14 & 88 - 10
#
# Каналы 88 & 14 - 13
#
# Каналы 89 & 14 - 16
#
# Каналы 92 & 14 - 10
#
# Каналы 93 & 14 - 10
#
# Каналы 94 & 14 - 11
#
# Каналы 14 & 95 - 3
#
# Каналы 96 & 14 - 8
#
# Каналы 14 & 97 - 12
#
# Каналы 97 & 14 - 7
#
# Каналы 14 & 98 - 8
#
# Каналы 14 & 99 - 14
#
# Каналы 15 & 16 - 9
#
# Каналы 15 & 18 - 15
#
# Каналы 18 & 15 - 13
#
# Каналы 15 & 19 - 9
#
# Каналы 15 & 22 - 5
#
# Каналы 22 & 15 - 7
#
# Каналы 15 & 23 - 6
#
# Каналы 15 & 24 - 10
#
# Каналы 15 & 25 - 15
#
# Каналы 25 & 15 - 9
#
# Каналы 15 & 26 - 6
#
# Каналы 15 & 27 - 12
#
# Каналы 15 & 29 - 14
#
# Каналы 29 & 15 - 16
#
# Каналы 15 & 30 - 7
#
# Каналы 15 & 31 - 12
#
# Каналы 31 & 15 - 12
#
# Каналы 15 & 32 - 14
#
# Каналы 15 & 33 - 10
#
# Каналы 34 & 15 - 8
#
# Каналы 35 & 15 - 12
#
# Каналы 36 & 15 - 9
#
# Каналы 37 & 15 - 14
#
# Каналы 15 & 38 - 9
#
# Каналы 15 & 39 - 10
#
# Каналы 40 & 15 - 12
#
# Каналы 15 & 41 - 9
#
# Каналы 41 & 15 - 7
#
# Каналы 15 & 42 - 10
#
# Каналы 15 & 43 - 8
#
# Каналы 43 & 15 - 6
#
# Каналы 15 & 44 - 9
#
# Каналы 15 & 45 - 9
#
# Каналы 15 & 46 - 11
#
# Каналы 15 & 47 - 14
#
# Каналы 15 & 49 - 12
#
# Каналы 15 & 52 - 6
#
# Каналы 15 & 54 - 14
#
# Каналы 55 & 15 - 7
#
# Каналы 57 & 15 - 6
#
# Каналы 58 & 15 - 7
#
# Каналы 61 & 15 - 10
#
# Каналы 15 & 62 - 8
#
# Каналы 62 & 15 - 19
#
# Каналы 63 & 15 - 11
#
# Каналы 64 & 15 - 11
#
# Каналы 65 & 15 - 10
#
# Каналы 15 & 67 - 5
#
# Каналы 68 & 15 - 8
#
# Каналы 70 & 15 - 14
#
# Каналы 15 & 72 - 9
#
# Каналы 72 & 15 - 12
#
# Каналы 15 & 73 - 13
#
# Каналы 73 & 15 - 10
#
# Каналы 15 & 74 - 10
#
# Каналы 74 & 15 - 12
#
# Каналы 15 & 75 - 13
#
# Каналы 76 & 15 - 12
#
# Каналы 15 & 77 - 10
#
# Каналы 15 & 78 - 8
#
# Каналы 79 & 15 - 5
#
# Каналы 15 & 80 - 12
#
# Каналы 80 & 15 - 4
#
# Каналы 15 & 82 - 9
#
# Каналы 82 & 15 - 11
#
# Каналы 15 & 83 - 8
#
# Каналы 83 & 15 - 8
#
# Каналы 84 & 15 - 5
#
# Каналы 15 & 85 - 5
#
# Каналы 85 & 15 - 8
#
# Каналы 15 & 86 - 12
#
# Каналы 15 & 89 - 14
#
# Каналы 89 & 15 - 11
#
# Каналы 15 & 90 - 9
#
# Каналы 15 & 91 - 8
#
# Каналы 91 & 15 - 13
#
# Каналы 15 & 92 - 11
#
# Каналы 92 & 15 - 9
#
# Каналы 15 & 94 - 9
#
# Каналы 94 & 15 - 4
#
# Каналы 15 & 95 - 10
#
# Каналы 95 & 15 - 7
#
# Каналы 97 & 15 - 11
#
# Каналы 15 & 98 - 9
#
# Каналы 16 & 17 - 14
#
# Каналы 16 & 18 - 7
#
# Каналы 18 & 16 - 6
#
# Каналы 19 & 16 - 9
#
# Каналы 16 & 20 - 10
#
# Каналы 16 & 21 - 11
#
# Каналы 16 & 22 - 8
#
# Каналы 22 & 16 - 8
#
# Каналы 16 & 23 - 9
#
# Каналы 24 & 16 - 8
#
# Каналы 16 & 25 - 5
#
# Каналы 25 & 16 - 13
#
# Каналы 26 & 16 - 9
#
# Каналы 16 & 28 - 16
#
# Каналы 28 & 16 - 14
#
# Каналы 16 & 30 - 4
#
# Каналы 30 & 16 - 7
#
# Каналы 31 & 16 - 12
#
# Каналы 33 & 16 - 6
#
# Каналы 35 & 16 - 5
#
# Каналы 37 & 16 - 11
#
# Каналы 16 & 38 - 8
#
# Каналы 38 & 16 - 11
#
# Каналы 16 & 39 - 5
#
# Каналы 39 & 16 - 18
#
# Каналы 16 & 41 - 13
#
# Каналы 43 & 16 - 10
#
# Каналы 16 & 46 - 10
#
# Каналы 47 & 16 - 13
#
# Каналы 16 & 48 - 9
#
# Каналы 48 & 16 - 4
#
# Каналы 16 & 49 - 8
#
# Каналы 16 & 50 - 8
#
# Каналы 50 & 16 - 6
#
# Каналы 16 & 52 - 12
#
# Каналы 16 & 53 - 17
#
# Каналы 53 & 16 - 8
#
# Каналы 16 & 55 - 9
#
# Каналы 56 & 16 - 8
#
# Каналы 57 & 16 - 18
#
# Каналы 16 & 58 - 7
#
# Каналы 16 & 59 - 9
#
# Каналы 60 & 16 - 10
#
# Каналы 62 & 16 - 8
#
# Каналы 16 & 63 - 9
#
# Каналы 63 & 16 - 14
#
# Каналы 16 & 64 - 16
#
# Каналы 64 & 16 - 11
#
# Каналы 16 & 65 - 11
#
# Каналы 65 & 16 - 12
#
# Каналы 66 & 16 - 11
#
# Каналы 68 & 16 - 7
#
# Каналы 16 & 70 - 12
#
# Каналы 16 & 71 - 14
#
# Каналы 16 & 72 - 18
#
# Каналы 16 & 73 - 13
#
# Каналы 73 & 16 - 8
#
# Каналы 74 & 16 - 12
#
# Каналы 75 & 16 - 10
#
# Каналы 16 & 77 - 9
#
# Каналы 16 & 79 - 9
#
# Каналы 81 & 16 - 14
#
# Каналы 16 & 84 - 10
#
# Каналы 84 & 16 - 7
#
# Каналы 87 & 16 - 11
#
# Каналы 90 & 16 - 13
#
# Каналы 91 & 16 - 9
#
# Каналы 16 & 92 - 9
#
# Каналы 93 & 16 - 14
#
# Каналы 94 & 16 - 9
#
# Каналы 97 & 16 - 9
#
# Каналы 19 & 17 - 15
#
# Каналы 21 & 17 - 9
#
# Каналы 22 & 17 - 10
#
# Каналы 17 & 23 - 13
#
# Каналы 23 & 17 - 6
#
# Каналы 17 & 25 - 8
#
# Каналы 25 & 17 - 6
#
# Каналы 17 & 27 - 8
#
# Каналы 28 & 17 - 8
#
# Каналы 17 & 29 - 6
#
# Каналы 17 & 30 - 16
#
# Каналы 31 & 17 - 10
#
# Каналы 32 & 17 - 8
#
# Каналы 17 & 33 - 3
#
# Каналы 34 & 17 - 12
#
# Каналы 35 & 17 - 10
#
# Каналы 17 & 36 - 9
#
# Каналы 36 & 17 - 9
#
# Каналы 17 & 37 - 12
#
# Каналы 37 & 17 - 6
#
# Каналы 17 & 38 - 15
#
# Каналы 38 & 17 - 8
#
# Каналы 17 & 39 - 12
#
# Каналы 40 & 17 - 11
#
# Каналы 17 & 41 - 7
#
# Каналы 41 & 17 - 6
#
# Каналы 17 & 42 - 5
#
# Каналы 42 & 17 - 9
#
# Каналы 17 & 48 - 9
#
# Каналы 48 & 17 - 8
#
# Каналы 50 & 17 - 11
#
# Каналы 17 & 51 - 11
#
# Каналы 51 & 17 - 11
#
# Каналы 17 & 52 - 7
#
# Каналы 52 & 17 - 7
#
# Каналы 55 & 17 - 5
#
# Каналы 56 & 17 - 13
#
# Каналы 17 & 58 - 7
#
# Каналы 59 & 17 - 12
#
# Каналы 17 & 60 - 10
#
# Каналы 17 & 61 - 6
#
# Каналы 62 & 17 - 8
#
# Каналы 17 & 63 - 8
#
# Каналы 17 & 64 - 9
#
# Каналы 64 & 17 - 10
#
# Каналы 17 & 65 - 8
#
# Каналы 65 & 17 - 8
#
# Каналы 17 & 66 - 14
#
# Каналы 17 & 68 - 13
#
# Каналы 70 & 17 - 13
#
# Каналы 17 & 71 - 6
#
# Каналы 71 & 17 - 8
#
# Каналы 17 & 74 - 7
#
# Каналы 77 & 17 - 10
#
# Каналы 17 & 80 - 11
#
# Каналы 80 & 17 - 7
#
# Каналы 17 & 81 - 11
#
# Каналы 81 & 17 - 8
#
# Каналы 17 & 82 - 9
#
# Каналы 17 & 83 - 7
#
# Каналы 84 & 17 - 11
#
# Каналы 85 & 17 - 10
#
# Каналы 17 & 86 - 7
#
# Каналы 17 & 87 - 8
#
# Каналы 17 & 88 - 12
#
# Каналы 88 & 17 - 6
#
# Каналы 17 & 89 - 13
#
# Каналы 17 & 90 - 5
#
# Каналы 91 & 17 - 12
#
# Каналы 17 & 92 - 10
#
# Каналы 17 & 93 - 9
#
# Каналы 93 & 17 - 13
#
# Каналы 17 & 95 - 10
#
# Каналы 17 & 97 - 14
#
# Каналы 97 & 17 - 15
#
# Каналы 98 & 17 - 11
#
# Каналы 17 & 99 - 13
#
# Каналы 18 & 19 - 14
#
# Каналы 19 & 18 - 4
#
# Каналы 18 & 21 - 13
#
# Каналы 22 & 18 - 12
#
# Каналы 18 & 23 - 7
#
# Каналы 23 & 18 - 8
#
# Каналы 24 & 18 - 10
#
# Каналы 18 & 25 - 9
#
# Каналы 26 & 18 - 6
#
# Каналы 18 & 27 - 8
#
# Каналы 27 & 18 - 10
#
# Каналы 18 & 28 - 10
#
# Каналы 29 & 18 - 8
#
# Каналы 18 & 30 - 4
#
# Каналы 32 & 18 - 12
#
# Каналы 18 & 33 - 7
#
# Каналы 18 & 34 - 8
#
# Каналы 18 & 35 - 14
#
# Каналы 18 & 36 - 17
#
# Каналы 18 & 37 - 7
#
# Каналы 38 & 18 - 12
#
# Каналы 18 & 39 - 9
#
# Каналы 39 & 18 - 10
#
# Каналы 40 & 18 - 15
#
# Каналы 18 & 42 - 4
#
# Каналы 18 & 43 - 8
#
# Каналы 43 & 18 - 7
#
# Каналы 18 & 44 - 10
#
# Каналы 44 & 18 - 9
#
# Каналы 18 & 46 - 12
#
# Каналы 49 & 18 - 13
#
# Каналы 18 & 51 - 6
#
# Каналы 18 & 52 - 9
#
# Каналы 52 & 18 - 8
#
# Каналы 18 & 53 - 10
#
# Каналы 18 & 54 - 16
#
# Каналы 54 & 18 - 10
#
# Каналы 18 & 56 - 7
#
# Каналы 57 & 18 - 12
#
# Каналы 18 & 60 - 12
#
# Каналы 60 & 18 - 9
#
# Каналы 62 & 18 - 4
#
# Каналы 18 & 63 - 9
#
# Каналы 63 & 18 - 6
#
# Каналы 64 & 18 - 11
#
# Каналы 18 & 66 - 13
#
# Каналы 18 & 67 - 14
#
# Каналы 67 & 18 - 7
#
# Каналы 68 & 18 - 13
#
# Каналы 18 & 69 - 9
#
# Каналы 71 & 18 - 8
#
# Каналы 18 & 72 - 8
#
# Каналы 18 & 73 - 11
#
# Каналы 18 & 74 - 12
#
# Каналы 74 & 18 - 9
#
# Каналы 18 & 75 - 5
#
# Каналы 75 & 18 - 5
#
# Каналы 18 & 76 - 7
#
# Каналы 18 & 78 - 10
#
# Каналы 78 & 18 - 10
#
# Каналы 18 & 79 - 16
#
# Каналы 79 & 18 - 9
#
# Каналы 18 & 82 - 6
#
# Каналы 82 & 18 - 9
#
# Каналы 18 & 83 - 12
#
# Каналы 18 & 84 - 9
#
# Каналы 18 & 85 - 11
#
# Каналы 86 & 18 - 12
#
# Каналы 18 & 89 - 7
#
# Каналы 89 & 18 - 9
#
# Каналы 90 & 18 - 6
#
# Каналы 18 & 91 - 12
#
# Каналы 91 & 18 - 8
#
# Каналы 18 & 92 - 10
#
# Каналы 92 & 18 - 11
#
# Каналы 94 & 18 - 9
#
# Каналы 96 & 18 - 15
#
# Каналы 97 & 18 - 12
#
# Каналы 18 & 99 - 13
#
# Каналы 99 & 18 - 6
#
# Каналы 19 & 21 - 6
#
# Каналы 19 & 22 - 16
#
# Каналы 22 & 19 - 7
#
# Каналы 19 & 23 - 9
#
# Каналы 23 & 19 - 12
#
# Каналы 19 & 24 - 8
#
# Каналы 24 & 19 - 11
#
# Каналы 19 & 27 - 9
#
# Каналы 27 & 19 - 12
#
# Каналы 19 & 28 - 6
#
# Каналы 19 & 29 - 8
#
# Каналы 19 & 30 - 13
#
# Каналы 19 & 31 - 9
#
# Каналы 31 & 19 - 10
#
# Каналы 19 & 32 - 8
#
# Каналы 19 & 34 - 7
#
# Каналы 34 & 19 - 12
#
# Каналы 19 & 35 - 9
#
# Каналы 35 & 19 - 10
#
# Каналы 19 & 39 - 13
#
# Каналы 39 & 19 - 11
#
# Каналы 19 & 40 - 13
#
# Каналы 41 & 19 - 15
#
# Каналы 19 & 43 - 8
#
# Каналы 19 & 44 - 11
#
# Каналы 44 & 19 - 13
#
# Каналы 19 & 45 - 4
#
# Каналы 46 & 19 - 6
#
# Каналы 19 & 47 - 7
#
# Каналы 19 & 48 - 12
#
# Каналы 19 & 49 - 10
#
# Каналы 19 & 51 - 13
#
# Каналы 51 & 19 - 10
#
# Каналы 52 & 19 - 6
#
# Каналы 54 & 19 - 10
#
# Каналы 19 & 56 - 18
#
# Каналы 56 & 19 - 11
#
# Каналы 57 & 19 - 11
#
# Каналы 58 & 19 - 10
#
# Каналы 59 & 19 - 13
#
# Каналы 19 & 60 - 7
#
# Каналы 19 & 61 - 10
#
# Каналы 61 & 19 - 9
#
# Каналы 19 & 62 - 11
#
# Каналы 62 & 19 - 5
#
# Каналы 63 & 19 - 10
#
# Каналы 19 & 65 - 7
#
# Каналы 66 & 19 - 10
#
# Каналы 19 & 67 - 4
#
# Каналы 67 & 19 - 7
#
# Каналы 19 & 68 - 6
#
# Каналы 68 & 19 - 9
#
# Каналы 19 & 69 - 17
#
# Каналы 69 & 19 - 6
#
# Каналы 19 & 70 - 13
#
# Каналы 70 & 19 - 8
#
# Каналы 19 & 71 - 14
#
# Каналы 71 & 19 - 15
#
# Каналы 72 & 19 - 7
#
# Каналы 19 & 73 - 10
#
# Каналы 73 & 19 - 9
#
# Каналы 19 & 74 - 9
#
# Каналы 19 & 75 - 12
#
# Каналы 75 & 19 - 7
#
# Каналы 76 & 19 - 9
#
# Каналы 19 & 77 - 10
#
# Каналы 19 & 78 - 10
#
# Каналы 78 & 19 - 14
#
# Каналы 19 & 79 - 7
#
# Каналы 79 & 19 - 12
#
# Каналы 19 & 80 - 11
#
# Каналы 80 & 19 - 7
#
# Каналы 19 & 81 - 11
#
# Каналы 19 & 82 - 10
#
# Каналы 19 & 83 - 12
#
# Каналы 83 & 19 - 10
#
# Каналы 84 & 19 - 2
#
# Каналы 85 & 19 - 11
#
# Каналы 86 & 19 - 10
#
# Каналы 87 & 19 - 6
#
# Каналы 19 & 88 - 10
#
# Каналы 89 & 19 - 11
#
# Каналы 90 & 19 - 14
#
# Каналы 91 & 19 - 9
#
# Каналы 92 & 19 - 8
#
# Каналы 95 & 19 - 10
#
# Каналы 96 & 19 - 8
#
# Каналы 19 & 97 - 11
#
# Каналы 19 & 99 - 6
#
# Каналы 21 & 20 - 11
#
# Каналы 20 & 23 - 12
#
# Каналы 24 & 20 - 6
#
# Каналы 20 & 25 - 12
#
# Каналы 26 & 20 - 8
#
# Каналы 27 & 20 - 7
#
# Каналы 29 & 20 - 12
#
# Каналы 30 & 20 - 11
#
# Каналы 20 & 32 - 13
#
# Каналы 20 & 33 - 8
#
# Каналы 33 & 20 - 9
#
# Каналы 20 & 34 - 6
#
# Каналы 20 & 35 - 7
#
# Каналы 20 & 36 - 7
#
# Каналы 36 & 20 - 9
#
# Каналы 20 & 37 - 9
#
# Каналы 37 & 20 - 11
#
# Каналы 20 & 38 - 6
#
# Каналы 38 & 20 - 12
#
# Каналы 39 & 20 - 12
#
# Каналы 40 & 20 - 8
#
# Каналы 20 & 41 - 8
#
# Каналы 41 & 20 - 13
#
# Каналы 20 & 44 - 17
#
# Каналы 20 & 45 - 15
#
# Каналы 20 & 46 - 11
#
# Каналы 47 & 20 - 11
#
# Каналы 48 & 20 - 5
#
# Каналы 49 & 20 - 9
#
# Каналы 20 & 50 - 9
#
# Каналы 50 & 20 - 12
#
# Каналы 20 & 51 - 10
#
# Каналы 51 & 20 - 6
#
# Каналы 20 & 52 - 13
#
# Каналы 52 & 20 - 6
#
# Каналы 54 & 20 - 11
#
# Каналы 20 & 55 - 8
#
# Каналы 20 & 56 - 12
#
# Каналы 57 & 20 - 8
#
# Каналы 58 & 20 - 9
#
# Каналы 63 & 20 - 12
#
# Каналы 64 & 20 - 12
#
# Каналы 20 & 65 - 10
#
# Каналы 20 & 66 - 5
#
# Каналы 20 & 67 - 10
#
# Каналы 67 & 20 - 12
#
# Каналы 68 & 20 - 11
#
# Каналы 20 & 69 - 7
#
# Каналы 20 & 70 - 10
#
# Каналы 20 & 71 - 8
#
# Каналы 71 & 20 - 10
#
# Каналы 72 & 20 - 12
#
# Каналы 20 & 73 - 11
#
# Каналы 73 & 20 - 10
#
# Каналы 20 & 74 - 8
#
# Каналы 74 & 20 - 5
#
# Каналы 20 & 75 - 11
#
# Каналы 75 & 20 - 11
#
# Каналы 20 & 76 - 9
#
# Каналы 20 & 77 - 8
#
# Каналы 77 & 20 - 10
#
# Каналы 20 & 78 - 10
#
# Каналы 20 & 79 - 10
#
# Каналы 79 & 20 - 14
#
# Каналы 20 & 80 - 7
#
# Каналы 80 & 20 - 9
#
# Каналы 20 & 81 - 8
#
# Каналы 81 & 20 - 10
#
# Каналы 20 & 82 - 7
#
# Каналы 20 & 83 - 6
#
# Каналы 83 & 20 - 8
#
# Каналы 20 & 85 - 9
#
# Каналы 86 & 20 - 6
#
# Каналы 20 & 87 - 10
#
# Каналы 20 & 88 - 9
#
# Каналы 88 & 20 - 6
#
# Каналы 20 & 89 - 9
#
# Каналы 89 & 20 - 18
#
# Каналы 20 & 90 - 9
#
# Каналы 20 & 91 - 10
#
# Каналы 91 & 20 - 5
#
# Каналы 20 & 92 - 11
#
# Каналы 92 & 20 - 12
#
# Каналы 20 & 93 - 7
#
# Каналы 20 & 94 - 4
#
# Каналы 94 & 20 - 7
#
# Каналы 20 & 95 - 10
#
# Каналы 95 & 20 - 5
#
# Каналы 20 & 96 - 8
#
# Каналы 97 & 20 - 11
#
# Каналы 20 & 98 - 12
#
# Каналы 98 & 20 - 11
#
# Каналы 21 & 22 - 9
#
# Каналы 22 & 21 - 11
#
# Каналы 21 & 23 - 12
#
# Каналы 23 & 21 - 15
#
# Каналы 21 & 24 - 12
#
# Каналы 21 & 25 - 9
#
# Каналы 25 & 21 - 17
#
# Каналы 26 & 21 - 6
#
# Каналы 21 & 27 - 6
#
# Каналы 27 & 21 - 4
#
# Каналы 29 & 21 - 7
#
# Каналы 21 & 30 - 7
#
# Каналы 21 & 31 - 8
#
# Каналы 31 & 21 - 9
#
# Каналы 21 & 32 - 14
#
# Каналы 33 & 21 - 11
#
# Каналы 21 & 34 - 8
#
# Каналы 34 & 21 - 16
#
# Каналы 35 & 21 - 8
#
# Каналы 21 & 36 - 7
#
# Каналы 21 & 37 - 7
#
# Каналы 37 & 21 - 7
#
# Каналы 21 & 38 - 13
#
# Каналы 39 & 21 - 6
#
# Каналы 21 & 40 - 11
#
# Каналы 21 & 41 - 7
#
# Каналы 21 & 42 - 11
#
# Каналы 21 & 43 - 12
#
# Каналы 21 & 44 - 3
#
# Каналы 21 & 45 - 7
#
# Каналы 46 & 21 - 9
#
# Каналы 21 & 47 - 7
#
# Каналы 47 & 21 - 10
#
# Каналы 49 & 21 - 14
#
# Каналы 21 & 50 - 11
#
# Каналы 21 & 51 - 10
#
# Каналы 51 & 21 - 13
#
# Каналы 21 & 52 - 18
#
# Каналы 21 & 53 - 6
#
# Каналы 54 & 21 - 5
#
# Каналы 21 & 56 - 15
#
# Каналы 56 & 21 - 9
#
# Каналы 58 & 21 - 12
#
# Каналы 21 & 62 - 8
#
# Каналы 62 & 21 - 8
#
# Каналы 21 & 63 - 10
#
# Каналы 21 & 65 - 5
#
# Каналы 65 & 21 - 12
#
# Каналы 21 & 66 - 10
#
# Каналы 21 & 67 - 12
#
# Каналы 67 & 21 - 13
#
# Каналы 21 & 68 - 6
#
# Каналы 21 & 72 - 8
#
# Каналы 21 & 73 - 12
#
# Каналы 73 & 21 - 13
#
# Каналы 21 & 74 - 14
#
# Каналы 74 & 21 - 6
#
# Каналы 76 & 21 - 10
#
# Каналы 21 & 77 - 11
#
# Каналы 21 & 79 - 15
#
# Каналы 80 & 21 - 7
#
# Каналы 21 & 82 - 9
#
# Каналы 21 & 83 - 9
#
# Каналы 21 & 84 - 3
#
# Каналы 84 & 21 - 9
#
# Каналы 21 & 85 - 14
#
# Каналы 85 & 21 - 12
#
# Каналы 86 & 21 - 8
#
# Каналы 21 & 88 - 5
#
# Каналы 88 & 21 - 10
#
# Каналы 21 & 89 - 10
#
# Каналы 21 & 91 - 14
#
# Каналы 21 & 92 - 8
#
# Каналы 92 & 21 - 9
#
# Каналы 21 & 93 - 4
#
# Каналы 93 & 21 - 10
#
# Каналы 94 & 21 - 10
#
# Каналы 21 & 95 - 10
#
# Каналы 21 & 97 - 10
#
# Каналы 97 & 21 - 11
#
# Каналы 21 & 99 - 10
#
# Каналы 99 & 21 - 12
#
# Каналы 22 & 23 - 10
#
# Каналы 26 & 22 - 9
#
# Каналы 22 & 27 - 9
#
# Каналы 22 & 29 - 6
#
# Каналы 22 & 30 - 12
#
# Каналы 30 & 22 - 10
#
# Каналы 32 & 22 - 11
#
# Каналы 22 & 33 - 10
#
# Каналы 33 & 22 - 9
#
# Каналы 22 & 34 - 14
#
# Каналы 34 & 22 - 8
#
# Каналы 22 & 36 - 13
#
# Каналы 22 & 37 - 7
#
# Каналы 39 & 22 - 9
#
# Каналы 40 & 22 - 9
#
# Каналы 22 & 41 - 13
#
# Каналы 41 & 22 - 11
#
# Каналы 22 & 42 - 13
#
# Каналы 43 & 22 - 9
#
# Каналы 44 & 22 - 15
#
# Каналы 22 & 45 - 16
#
# Каналы 45 & 22 - 11
#
# Каналы 46 & 22 - 10
#
# Каналы 48 & 22 - 10
#
# Каналы 22 & 49 - 13
#
# Каналы 49 & 22 - 10
#
# Каналы 22 & 51 - 11
#
# Каналы 22 & 52 - 5
#
# Каналы 22 & 53 - 7
#
# Каналы 53 & 22 - 10
#
# Каналы 22 & 55 - 9
#
# Каналы 22 & 56 - 10
#
# Каналы 56 & 22 - 14
#
# Каналы 22 & 57 - 16
#
# Каналы 57 & 22 - 7
#
# Каналы 22 & 58 - 9
#
# Каналы 58 & 22 - 13
#
# Каналы 60 & 22 - 19
#
# Каналы 22 & 64 - 12
#
# Каналы 64 & 22 - 11
#
# Каналы 22 & 66 - 13
#
# Каналы 67 & 22 - 9
#
# Каналы 22 & 69 - 12
#
# Каналы 70 & 22 - 5
#
# Каналы 22 & 71 - 7
#
# Каналы 72 & 22 - 14
#
# Каналы 22 & 74 - 6
#
# Каналы 22 & 75 - 6
#
# Каналы 75 & 22 - 8
#
# Каналы 22 & 77 - 5
#
# Каналы 77 & 22 - 12
#
# Каналы 78 & 22 - 12
#
# Каналы 79 & 22 - 9
#
# Каналы 22 & 80 - 9
#
# Каналы 81 & 22 - 12
#
# Каналы 22 & 83 - 15
#
# Каналы 83 & 22 - 5
#
# Каналы 22 & 84 - 10
#
# Каналы 84 & 22 - 6
#
# Каналы 22 & 85 - 9
#
# Каналы 85 & 22 - 9
#
# Каналы 22 & 86 - 8
#
# Каналы 86 & 22 - 8
#
# Каналы 87 & 22 - 12
#
# Каналы 90 & 22 - 8
#
# Каналы 22 & 91 - 6
#
# Каналы 22 & 92 - 10
#
# Каналы 92 & 22 - 10
#
# Каналы 22 & 93 - 17
#
# Каналы 93 & 22 - 7
#
# Каналы 22 & 96 - 10
#
# Каналы 22 & 97 - 12
#
# Каналы 97 & 22 - 8
#
# Каналы 22 & 98 - 8
#
# Каналы 99 & 22 - 9
#
# Каналы 23 & 24 - 9
#
# Каналы 24 & 23 - 10
#
# Каналы 23 & 25 - 9
#
# Каналы 23 & 27 - 7
#
# Каналы 27 & 23 - 6
#
# Каналы 23 & 30 - 9
#
# Каналы 30 & 23 - 13
#
# Каналы 31 & 23 - 9
#
# Каналы 32 & 23 - 9
#
# Каналы 23 & 33 - 9
#
# Каналы 33 & 23 - 12
#
# Каналы 34 & 23 - 14
#
# Каналы 23 & 36 - 10
#
# Каналы 23 & 41 - 8
#
# Каналы 23 & 43 - 11
#
# Каналы 43 & 23 - 11
#
# Каналы 23 & 44 - 10
#
# Каналы 23 & 45 - 8
#
# Каналы 45 & 23 - 12
#
# Каналы 23 & 47 - 10
#
# Каналы 47 & 23 - 11
#
# Каналы 23 & 48 - 12
#
# Каналы 23 & 50 - 11
#
# Каналы 23 & 51 - 13
#
# Каналы 23 & 54 - 11
#
# Каналы 54 & 23 - 9
#
# Каналы 23 & 55 - 11
#
# Каналы 55 & 23 - 14
#
# Каналы 23 & 58 - 10
#
# Каналы 58 & 23 - 13
#
# Каналы 60 & 23 - 13
#
# Каналы 61 & 23 - 11
#
# Каналы 23 & 62 - 6
#
# Каналы 62 & 23 - 13
#
# Каналы 23 & 63 - 7
#
# Каналы 23 & 64 - 8
#
# Каналы 23 & 65 - 8
#
# Каналы 65 & 23 - 8
#
# Каналы 23 & 66 - 6
#
# Каналы 66 & 23 - 9
#
# Каналы 67 & 23 - 13
#
# Каналы 23 & 71 - 12
#
# Каналы 23 & 72 - 16
#
# Каналы 72 & 23 - 10
#
# Каналы 23 & 73 - 12
#
# Каналы 73 & 23 - 18
#
# Каналы 23 & 74 - 10
#
# Каналы 74 & 23 - 10
#
# Каналы 23 & 75 - 11
#
# Каналы 75 & 23 - 7
#
# Каналы 23 & 76 - 12
#
# Каналы 23 & 78 - 6
#
# Каналы 79 & 23 - 11
#
# Каналы 23 & 82 - 11
#
# Каналы 23 & 83 - 14
#
# Каналы 23 & 87 - 14
#
# Каналы 23 & 88 - 10
#
# Каналы 88 & 23 - 10
#
# Каналы 23 & 89 - 10
#
# Каналы 89 & 23 - 14
#
# Каналы 23 & 90 - 7
#
# Каналы 90 & 23 - 12
#
# Каналы 91 & 23 - 10
#
# Каналы 92 & 23 - 13
#
# Каналы 93 & 23 - 16
#
# Каналы 94 & 23 - 9
#
# Каналы 23 & 98 - 13
#
# Каналы 98 & 23 - 6
#
# Каналы 24 & 25 - 5
#
# Каналы 26 & 24 - 8
#
# Каналы 27 & 24 - 10
#
# Каналы 24 & 29 - 6
#
# Каналы 33 & 24 - 11
#
# Каналы 34 & 24 - 10
#
# Каналы 24 & 35 - 7
#
# Каналы 24 & 36 - 9
#
# Каналы 24 & 37 - 16
#
# Каналы 37 & 24 - 14
#
# Каналы 38 & 24 - 6
#
# Каналы 40 & 24 - 12
#
# Каналы 41 & 24 - 8
#
# Каналы 24 & 42 - 5
#
# Каналы 43 & 24 - 8
#
# Каналы 24 & 44 - 8
#
# Каналы 24 & 46 - 13
#
# Каналы 48 & 24 - 7
#
# Каналы 24 & 49 - 12
#
# Каналы 49 & 24 - 15
#
# Каналы 24 & 50 - 10
#
# Каналы 24 & 51 - 8
#
# Каналы 51 & 24 - 10
#
# Каналы 24 & 53 - 12
#
# Каналы 24 & 54 - 7
#
# Каналы 54 & 24 - 10
#
# Каналы 24 & 55 - 6
#
# Каналы 55 & 24 - 11
#
# Каналы 24 & 56 - 12
#
# Каналы 24 & 57 - 8
#
# Каналы 57 & 24 - 13
#
# Каналы 24 & 58 - 13
#
# Каналы 24 & 59 - 7
#
# Каналы 59 & 24 - 8
#
# Каналы 60 & 24 - 7
#
# Каналы 24 & 61 - 14
#
# Каналы 64 & 24 - 11
#
# Каналы 24 & 66 - 11
#
# Каналы 66 & 24 - 7
#
# Каналы 24 & 67 - 10
#
# Каналы 67 & 24 - 12
#
# Каналы 24 & 68 - 9
#
# Каналы 69 & 24 - 13
#
# Каналы 70 & 24 - 16
#
# Каналы 24 & 71 - 8
#
# Каналы 71 & 24 - 11
#
# Каналы 24 & 73 - 14
#
# Каналы 24 & 74 - 9
#
# Каналы 74 & 24 - 11
#
# Каналы 75 & 24 - 14
#
# Каналы 24 & 77 - 11
#
# Каналы 24 & 78 - 12
#
# Каналы 24 & 79 - 13
#
# Каналы 79 & 24 - 5
#
# Каналы 24 & 80 - 9
#
# Каналы 24 & 82 - 10
#
# Каналы 82 & 24 - 12
#
# Каналы 24 & 84 - 7
#
# Каналы 85 & 24 - 10
#
# Каналы 24 & 86 - 9
#
# Каналы 24 & 87 - 12
#
# Каналы 87 & 24 - 7
#
# Каналы 24 & 88 - 10
#
# Каналы 88 & 24 - 11
#
# Каналы 24 & 89 - 9
#
# Каналы 24 & 90 - 11
#
# Каналы 90 & 24 - 15
#
# Каналы 24 & 91 - 13
#
# Каналы 91 & 24 - 9
#
# Каналы 24 & 92 - 8
#
# Каналы 92 & 24 - 11
#
# Каналы 24 & 93 - 13
#
# Каналы 24 & 94 - 10
#
# Каналы 94 & 24 - 15
#
# Каналы 24 & 95 - 14
#
# Каналы 24 & 97 - 10
#
# Каналы 24 & 98 - 8
#
# Каналы 24 & 99 - 8
#
# Каналы 99 & 24 - 8
#
# Каналы 25 & 27 - 9
#
# Каналы 27 & 25 - 8
#
# Каналы 25 & 28 - 10
#
# Каналы 25 & 29 - 12
#
# Каналы 25 & 31 - 6
#
# Каналы 25 & 34 - 8
#
# Каналы 25 & 35 - 8
#
# Каналы 36 & 25 - 12
#
# Каналы 25 & 37 - 13
#
# Каналы 25 & 39 - 11
#
# Каналы 40 & 25 - 10
#
# Каналы 25 & 41 - 14
#
# Каналы 42 & 25 - 12
#
# Каналы 43 & 25 - 9
#
# Каналы 25 & 44 - 9
#
# Каналы 44 & 25 - 12
#
# Каналы 25 & 45 - 9
#
# Каналы 45 & 25 - 15
#
# Каналы 25 & 46 - 8
#
# Каналы 46 & 25 - 11
#
# Каналы 25 & 47 - 8
#
# Каналы 47 & 25 - 12
#
# Каналы 48 & 25 - 7
#
# Каналы 25 & 49 - 13
#
# Каналы 25 & 50 - 9
#
# Каналы 25 & 53 - 5
#
# Каналы 54 & 25 - 7
#
# Каналы 56 & 25 - 6
#
# Каналы 57 & 25 - 13
#
# Каналы 58 & 25 - 8
#
# Каналы 25 & 59 - 12
#
# Каналы 25 & 61 - 9
#
# Каналы 61 & 25 - 7
#
# Каналы 25 & 62 - 9
#
# Каналы 62 & 25 - 17
#
# Каналы 64 & 25 - 15
#
# Каналы 67 & 25 - 11
#
# Каналы 25 & 68 - 8
#
# Каналы 68 & 25 - 8
#
# Каналы 69 & 25 - 7
#
# Каналы 25 & 70 - 11
#
# Каналы 70 & 25 - 14
#
# Каналы 71 & 25 - 10
#
# Каналы 25 & 72 - 9
#
# Каналы 73 & 25 - 11
#
# Каналы 74 & 25 - 12
#
# Каналы 76 & 25 - 11
#
# Каналы 78 & 25 - 7
#
# Каналы 25 & 79 - 13
#
# Каналы 79 & 25 - 11
#
# Каналы 25 & 80 - 5
#
# Каналы 81 & 25 - 9
#
# Каналы 25 & 82 - 9
#
# Каналы 25 & 83 - 9
#
# Каналы 83 & 25 - 13
#
# Каналы 84 & 25 - 8
#
# Каналы 25 & 86 - 18
#
# Каналы 86 & 25 - 6
#
# Каналы 25 & 88 - 8
#
# Каналы 88 & 25 - 11
#
# Каналы 89 & 25 - 16
#
# Каналы 25 & 90 - 11
#
# Каналы 90 & 25 - 7
#
# Каналы 25 & 91 - 10
#
# Каналы 91 & 25 - 14
#
# Каналы 25 & 92 - 12
#
# Каналы 92 & 25 - 11
#
# Каналы 25 & 93 - 12
#
# Каналы 93 & 25 - 11
#
# Каналы 94 & 25 - 10
#
# Каналы 25 & 95 - 4
#
# Каналы 97 & 25 - 9
#
# Каналы 25 & 98 - 15
#
# Каналы 98 & 25 - 12
#
# ...
#
# Канал 44 публикует информативный пост.
#
# Канал 45 публикует сенситивный пост.
#
# Канал 46 публикует информативный пост.
#
# Канал 47 публикует сенситивный пост.
#
# Канал 48 публикует информативный пост.
#
# Канал 49 публикует информативный пост.
#
# Канал 50 публикует информативный пост.
#
# Канал 51 публикует информативный пост.
#
# Канал 52 публикует информативный пост.
#
# Канал 53 публикует информативный пост.
#
# Канал 54 публикует информативный пост.
#
# Канал 55 публикует сенситивный пост.
#
# Канал 56 публикует сенситивный пост.
#
# Канал 57 публикует информативный пост.
#
# Канал 58 публикует информативный пост.
#
# Канал 59 публикует информативный пост.
#
# Канал 60 публикует информативный пост.
#
# Канал 61 публикует информативный пост.
#
# Канал 62 публикует сенситивный пост.
#
# Канал 63 публикует информативный пост.
#
# Канал 64 публикует информативный пост.
#
# Канал 65 публикует информативный пост.
#
# Канал 66 публикует сенситивный пост.
#
# Канал 67 публикует информативный пост.
#
# Канал 68 публикует сенситивный пост.
#
# Канал 69 публикует информативный пост.
#
# Канал 70 публикует сенситивный пост.
#
# Канал 71 публикует информативный пост.
#
# Канал 72 публикует информативный пост.
#
# Канал 73 публикует информативный пост.
#
# Канал 74 публикует информативный пост.
#
# Канал 75 публикует информативный пост.
#
# Канал 76 публикует информативный пост.
#
# Канал 77 публикует информативный пост.
#
# Канал 78 публикует информативный пост.
#
# Канал 79 публикует информативный пост.
#
# Канал 80 публикует информативный пост.
#
# Канал 81 публикует информативный пост.
#
# Канал 82 публикует информативный пост.
#
# Канал 83 публикует информативный пост.
#
# Канал 84 публикует сенситивный пост.
#
# Канал 85 публикует сенситивный пост.
#
# Канал 86 публикует информативный пост.
#
# Канал 87 публикует сенситивный пост.
#
# Канал 88 публикует информативный пост.
#
# Канал 89 публикует информативный пост.
#
# Канал 90 публикует сенситивный пост.
#
# Канал 91 публикует сенситивный пост.
#
# Канал 92 публикует информативный пост.
#
# Канал 93 публикует информативный пост.
#
# Канал 94 публикует информативный пост.
#
# Канал 95 публикует информативный пост.
#
# Канал 96 публикует сенситивный пост.
#
# Канал 97 публикует информативный пост.
#
# Канал 98 публикует информативный пост.
#
# Канал 99 публикует информативный пост.
#
#
#
# Канал 0 : 1 подп.
#
# Канал 2 : 5966 подп.
#
# Канал 3 : 1 подп.
#
# Канал 4 : 3002 подп.
#
# Канал 5 : 2564 подп.
#
# Канал 6 : 982 подп.
#
# Канал 7 : 1 подп.
#
# Канал 8 : 1 подп.
#
# Канал 9 : 1 подп.
#
# Канал 10 : 1 подп.
#
# Канал 11 : 652 подп.
#
# Канал 12 : 1 подп.
#
# Канал 13 : 1 подп.
#
# Канал 14 : 1 подп.
#
# Канал 15 : 1 подп.
#
# Канал 16 : 1 подп.
#
# Канал 17 : 1 подп.
#
# Канал 18 : 1 подп.
#
# Канал 19 : 1 подп.
#
# Канал 20 : 1 подп.
#
# Канал 21 : 1 подп.
#
# Канал 22 : 1 подп.
#
# Канал 23 : 1 подп.
#
# Канал 24 : 1 подп.
#
# Канал 25 : 1 подп.
#
# Канал 26 : 1 подп.
#
# Канал 27 : 1 подп.
#
# Канал 28 : 435 подп.
#
# Канал 29 : 1 подп.
#
# Канал 30 : 350 подп.
#
# Канал 31 : 432 подп.
#
# Канал 32 : 1 подп.
#
# Канал 33 : 263 подп.
#
# Канал 34 : 1 подп.
#
# Канал 35 : 1 подп.
#
# Канал 36 : 1 подп.
#
# Канал 38 : 251 подп.
#
# Канал 39 : 407 подп.
#
# Канал 40 : 1 подп.
#
# Канал 41 : 1 подп.
#
# Канал 42 : 285 подп.
#
# Канал 43 : 1 подп.
#
# Канал 44 : 1 подп.
#
# Канал 45 : 251 подп.
#
# Канал 46 : 1 подп.
#
# Канал 47 : 328 подп.
#
# Канал 48 : 1 подп.
#
# Канал 49 : 1 подп.
#
# Канал 50 : 1 подп.
#
# Канал 51 : 1 подп.
#
# Канал 52 : 1 подп.
#
# Канал 53 : 1 подп.
#
# Канал 54 : 1 подп.
#
# Канал 55 : 297 подп.
#
# Канал 56 : 254 подп.
#
# Канал 57 : 1 подп.
#
# Канал 58 : 1 подп.
#
# Канал 59 : 1 подп.
#
# Канал 60 : 1 подп.
#
# Канал 61 : 1 подп.
#
# Канал 62 : 260 подп.
#
# Канал 63 : 1 подп.
#
# Канал 64 : 1 подп.
#
# Канал 65 : 1 подп.
#
# Канал 66 : 285 подп.
#
# Канал 67 : 1 подп.
#
# Канал 68 : 288 подп.
#
# Канал 69 : 1 подп.
#
# Канал 70 : 305 подп.
#
# Канал 71 : 1 подп.
#
# Канал 72 : 1 подп.
#
# Канал 73 : 1 подп.
#
# Канал 74 : 1 подп.
#
# Канал 75 : 1 подп.
#
# Канал 76 : 1 подп.
#
# Канал 77 : 1 подп.
#
# Канал 78 : 1 подп.
#
# Канал 79 : 1 подп.
#
# Канал 80 : 1 подп.
#
# Канал 81 : 1 подп.
#
# Канал 82 : 1 подп.
#
# Канал 83 : 1 подп.
#
# Канал 84 : 272 подп.
#
# Канал 85 : 257 подп.
#
# Канал 86 : 1 подп.
#
# Канал 87 : 278 подп.
#
# Канал 88 : 1 подп.
#
# Канал 89 : 1 подп.
#
# Канал 90 : 250 подп.
#
# Канал 91 : 268 подп.
#
# Канал 92 : 1 подп.
#
# Канал 93 : 1 подп.
#
# Канал 94 : 1 подп.
#
# Канал 95 : 1 подп.
#
# Канал 96 : 270 подп.
#
# Канал 97 : 1 подп.
#
# Канал 98 : 1 подп.
#
# Канал 99 : 1 подп.
#
# Раунд 9
#
# Канал 0 публикует информативный пост.
#
# Канал 2 публикует сенситивный пост.
#
# Канал 3 публикует информативный пост.
#
# Канал 4 публикует сенситивный пост.
#
# Канал 5 публикует сенситивный пост.
#
# Канал 6 публикует сенситивный пост.
#
# Канал 7 публикует информативный пост.
#
# Канал 8 публикует информативный пост.
#
# Канал 9 публикует информативный пост.
#
# Канал 10 публикует информативный пост.
#
# Канал 11 публикует сенситивный пост.
#
# Канал 12 публикует информативный пост.
#
# Канал 13 публикует информативный пост.
#
# Канал 14 публикует информативный пост.
#
# Канал 15 публикует информативный пост.
#
# Канал 16 публикует информативный пост.
#
# Канал 17 публикует информативный пост.
#
# Канал 18 публикует информативный пост.
#
# Канал 19 публикует информативный пост.
#
# Канал 20 публикует информативный пост.
#
# Канал 21 публикует информативный пост.
#
# Канал 22 публикует информативный пост.
#
# Канал 23 публикует информативный пост.
#
# Канал 24 публикует информативный пост.
#
# Канал 25 публикует информативный пост.
#
# Канал 26 публикует информативный пост.
#
# Канал 27 публикует информативный пост.
#
# Канал 28 публикует сенситивный пост.
#
# Канал 29 публикует информативный пост.
#
# Канал 30 публикует сенситивный пост.
#
# Канал 31 публикует сенситивный пост.
#
# Канал 32 публикует информативный пост.
#
# Канал 33 публикует сенситивный пост.
#
# Канал 34 публикует информативный пост.
#
# Канал 35 публикует информативный пост.
#
# Канал 36 публикует информативный пост.
#
# Канал 38 публикует сенситивный пост.
#
# Канал 39 публикует сенситивный пост.
#
# Канал 40 публикует информативный пост.
#
# Канал 41 публикует информативный пост.
#
# Канал 42 публикует сенситивный пост.
#
# Канал 43 публикует информативный пост.
#
# Канал 44 публикует информативный пост.
#
# Канал 45 публикует сенситивный пост.
#
# Канал 46 публикует информативный пост.
#
# Канал 47 публикует сенситивный пост.
#
# Канал 48 публикует информативный пост.
#
# Канал 49 публикует информативный пост.
#
# Канал 50 публикует информативный пост.
#
# Канал 51 публикует информативный пост.
#
# Канал 52 публикует информативный пост.
#
# Канал 53 публикует информативный пост.
#
# Канал 54 публикует информативный пост.
#
# Канал 55 публикует сенситивный пост.
#
# Канал 56 публикует сенситивный пост.
#
# Канал 57 публикует информативный пост.
#
# Канал 58 публикует информативный пост.
#
# Канал 59 публикует информативный пост.
#
# Канал 60 публикует информативный пост.
#
# Канал 61 публикует информативный пост.
#
# Канал 62 публикует сенситивный пост.
#
# Канал 63 публикует информативный пост.
#
# Канал 64 публикует информативный пост.
#
# Канал 65 публикует информативный пост.
#
# Канал 66 публикует сенситивный пост.
#
# Канал 67 публикует информативный пост.
#
# Канал 68 публикует сенситивный пост.
#
# Канал 69 публикует информативный пост.
#
# Канал 70 публикует сенситивный пост.
#
# Канал 71 публикует информативный пост.
#
# Канал 72 публикует информативный пост.
#
# Канал 73 публикует информативный пост.
#
# Канал 74 публикует информативный пост.
#
# Канал 75 публикует информативный пост.
#
# Канал 76 публикует информативный пост.
#
# Канал 77 публикует информативный пост.
#
# Канал 78 публикует информативный пост.
#
# Канал 79 публикует информативный пост.
#
# Канал 80 публикует информативный пост.
#
# Канал 81 публикует информативный пост.
#
# Канал 82 публикует информативный пост.
#
# Канал 83 публикует информативный пост.
#
# Канал 84 публикует сенситивный пост.
#
# Канал 85 публикует сенситивный пост.
#
# Канал 86 публикует информативный пост.
#
# Канал 87 публикует сенситивный пост.
#
# Канал 88 публикует информативный пост.
#
# Канал 89 публикует информативный пост.
#
# Канал 90 публикует сенситивный пост.
#
# Канал 91 публикует сенситивный пост.
#
# Канал 92 публикует информативный пост.
#
# Канал 93 публикует информативный пост.
#
# Канал 94 публикует информативный пост.
#
# Канал 95 публикует информативный пост.
#
# Канал 96 публикует сенситивный пост.
#
# Канал 97 публикует информативный пост.
#
# Канал 98 публикует информативный пост.
#
# Канал 99 публикует информативный пост.
#
#
#
# Канал 0 : 1 подп.
#
# Канал 2 : 5966 подп.
#
# Канал 3 : 1 подп.
#
# Канал 4 : 3002 подп.
#
# Канал 5 : 2564 подп.
#
# Канал 6 : 982 подп.
#
# Канал 7 : 1 подп.
#
# Канал 8 : 1 подп.
#
# Канал 9 : 1 подп.
#
# Канал 10 : 1 подп.
#
# Канал 11 : 652 подп.
#
# Канал 12 : 1 подп.
#
# Канал 13 : 1 подп.
#
# Канал 14 : 1 подп.
#
# Канал 15 : 1 подп.
#
# Канал 16 : 1 подп.
#
# Канал 17 : 1 подп.
#
# Канал 18 : 1 подп.
#
# Канал 19 : 1 подп.
#
# Канал 20 : 1 подп.
#
# Канал 21 : 1 подп.
#
# Канал 22 : 1 подп.
#
# Канал 23 : 1 подп.
#
# Канал 24 : 1 подп.
#
# Канал 25 : 1 подп.
#
# Канал 26 : 1 подп.
#
# Канал 27 : 1 подп.
#
# Канал 28 : 435 подп.
#
# Канал 29 : 1 подп.
#
# Канал 30 : 350 подп.
#
# Канал 31 : 432 подп.
#
# Канал 32 : 1 подп.
#
# Канал 33 : 263 подп.
#
# Канал 34 : 1 подп.
#
# Канал 35 : 1 подп.
#
# Канал 36 : 1 подп.
#
# Канал 38 : 251 подп.
#
# Канал 39 : 407 подп.
#
# Канал 40 : 1 подп.
#
# Канал 41 : 1 подп.
#
# Канал 42 : 285 подп.
#
# Канал 43 : 1 подп.
#
# Канал 44 : 1 подп.
#
# Канал 45 : 251 подп.
#
# Канал 46 : 1 подп.
#
# Канал 47 : 328 подп.
#
# Канал 48 : 1 подп.
#
# Канал 49 : 1 подп.
#
# Канал 50 : 1 подп.
#
# Канал 51 : 1 подп.
#
# Канал 52 : 1 подп.
#
# Канал 53 : 1 подп.
#
# Канал 54 : 1 подп.
#
# Канал 55 : 297 подп.
#
# Канал 56 : 254 подп.
#
# Канал 57 : 1 подп.
#
# Канал 58 : 1 подп.
#
# Канал 59 : 1 подп.
#
# Канал 60 : 1 подп.
#
# Канал 61 : 1 подп.
#
# Канал 62 : 260 подп.
#
# Канал 63 : 1 подп.
#
# Канал 64 : 1 подп.
#
# Канал 65 : 1 подп.
#
# Канал 66 : 285 подп.
#
# Канал 67 : 1 подп.
#
# Канал 68 : 288 подп.
#
# Канал 69 : 1 подп.
#
# Канал 70 : 305 подп.
#
# Канал 71 : 1 подп.
#
# Канал 72 : 1 подп.
#
# Канал 73 : 1 подп.
#
# Канал 74 : 1 подп.
#
# Канал 75 : 1 подп.
#
# Канал 76 : 1 подп.
#
# Канал 77 : 1 подп.
#
# Канал 78 : 1 подп.
#
# Канал 79 : 1 подп.
#
# Канал 80 : 1 подп.
#
# Канал 81 : 1 подп.
#
# Канал 82 : 1 подп.
#
# Канал 83 : 1 подп.
#
# Канал 84 : 272 подп.
#
# Канал 85 : 257 подп.
#
# Канал 86 : 1 подп.
#
# Канал 87 : 278 подп.
#
# Канал 88 : 1 подп.
#
# Канал 89 : 1 подп.
#
# Канал 90 : 250 подп.
#
# Канал 91 : 268 подп.
#
# Канал 92 : 1 подп.
#
# Канал 93 : 1 подп.
#
# Канал 94 : 1 подп.
#
# Канал 95 : 1 подп.
#
# Канал 96 : 270 подп.
#
# Канал 97 : 1 подп.
#
# Канал 98 : 1 подп.
#
# Канал 99 : 1 подп.
#
# Раунд 10
#
# Канал 0 публикует информативный пост.
#
# Канал 2 публикует сенситивный пост.
#
# Канал 3 публикует информативный пост.
#
# Канал 4 публикует сенситивный пост.
#
# Канал 5 публикует сенситивный пост.
#
# Канал 6 публикует сенситивный пост.
#
# Канал 7 публикует информативный пост.
#
# Канал 8 публикует информативный пост.
#
# Канал 9 публикует информативный пост.
#
# Канал 10 публикует информативный пост.
#
# Канал 11 публикует сенситивный пост.
#
# Канал 12 публикует информативный пост.
#
# Канал 13 публикует информативный пост.
#
# Канал 14 публикует информативный пост.
#
# Канал 15 публикует информативный пост.
#
# Канал 16 публикует информативный пост.
#
# Канал 17 публикует информативный пост.
#
# Канал 18 публикует информативный пост.
#
# Канал 19 публикует информативный пост.
#
# Канал 20 публикует информативный пост.
#
# Канал 21 публикует информативный пост.
#
# Канал 22 публикует информативный пост.
#
# Канал 23 публикует информативный пост.
#
# Канал 24 публикует информативный пост.
#
# Канал 25 публикует информативный пост.
#
# Канал 26 публикует информативный пост.
#
# Канал 27 публикует информативный пост.
#
# Канал 28 публикует сенситивный пост.
#
# Канал 29 публикует информативный пост.
#
# Канал 30 публикует сенситивный пост.
#
# Канал 31 публикует сенситивный пост.
#
# Канал 32 публикует информативный пост.
#
# Канал 33 публикует сенситивный пост.
#
# Канал 34 публикует информативный пост.
#
# Канал 35 публикует информативный пост.
#
# Канал 36 публикует информативный пост.
#
# Канал 38 публикует сенситивный пост.
#
# Канал 39 публикует сенситивный пост.
#
# Канал 40 публикует информативный пост.
#
# Канал 41 публикует информативный пост.
#
# Канал 42 публикует сенситивный пост.
#
# Канал 43 публикует информативный пост.
#
# Канал 44 публикует информативный пост.
#
# Канал 45 публикует сенситивный пост.
#
# Канал 46 публикует информативный пост.
#
# Канал 47 публикует сенситивный пост.
#
# Канал 48 публикует информативный пост.
#
# Канал 49 публикует информативный пост.
#
# Канал 50 публикует информативный пост.
#
# Канал 51 публикует информативный пост.
#
# Канал 52 публикует информативный пост.
#
# Канал 53 публикует информативный пост.
#
# Канал 54 публикует информативный пост.
#
# Канал 55 публикует сенситивный пост.
#
# Канал 56 публикует сенситивный пост.
#
# Канал 57 публикует информативный пост.
#
# Канал 58 публикует информативный пост.
#
# Канал 59 публикует информативный пост.
#
# Канал 60 публикует информативный пост.
#
# Канал 61 публикует информативный пост.
#
# Канал 62 публикует сенситивный пост.
#
# Канал 63 публикует информативный пост.
#
# Канал 64 публикует информативный пост.
#
# Канал 65 публикует информативный пост.
#
# Канал 66 публикует сенситивный пост.
#
# Канал 67 публикует информативный пост.
#
# Канал 68 публикует сенситивный пост.
#
# Канал 69 публикует информативный пост.
#
# Канал 70 публикует сенситивный пост.
#
# Канал 71 публикует информативный пост.
#
# Канал 72 публикует информативный пост.
#
# Канал 73 публикует информативный пост.
#
# Канал 74 публикует информативный пост.
#
# Канал 75 публикует информативный пост.
#
# Канал 76 публикует информативный пост.
#
# Канал 77 публикует информативный пост.
#
# Канал 78 публикует информативный пост.
#
# Канал 79 публикует информативный пост.
#
# Канал 80 публикует информативный пост.
#
# Канал 81 публикует информативный пост.
#
# Канал 82 публикует информативный пост.
#
# Канал 83 публикует информативный пост.
#
# Канал 84 публикует сенситивный пост.
#
# Канал 85 публикует сенситивный пост.
#
# Канал 86 публикует информативный пост.
#
# Канал 87 публикует сенситивный пост.
#
# Канал 88 публикует информативный пост.
#
# Канал 89 публикует информативный пост.
#
# Канал 90 публикует сенситивный пост.
#
# Канал 91 публикует сенситивный пост.
#
# Канал 92 публикует информативный пост.
#
# Канал 93 публикует информативный пост.
#
# Канал 94 публикует информативный пост.
#
# Канал 95 публикует информативный пост.
#
# Канал 96 публикует сенситивный пост.
#
# Канал 97 публикует информативный пост.
#
# Канал 98 публикует информативный пост.
#
# Канал 99 публикует информативный пост.
#
#
#
# Канал 0 : 1 подп.
#
# Канал 2 : 5966 подп.
#
# Канал 3 : 1 подп.
#
# Канал 4 : 3002 подп.
#
# Канал 5 : 2564 подп.
#
# Канал 6 : 982 подп.
#
# Канал 7 : 1 подп.
#
# Канал 8 : 1 подп.
#
# Канал 9 : 1 подп.
#
# Канал 10 : 1 подп.
#
# Канал 11 : 652 подп.
#
# Канал 12 : 1 подп.
#
# Канал 13 : 1 подп.
#
# Канал 14 : 1 подп.
#
# Канал 15 : 1 подп.
#
# Канал 16 : 1 подп.
#
# Канал 17 : 1 подп.
#
# Канал 18 : 1 подп.
#
# Канал 19 : 1 подп.
#
# Канал 20 : 1 подп.
#
# Канал 21 : 1 подп.
#
# Канал 22 : 1 подп.
#
# Канал 23 : 1 подп.
#
# Канал 24 : 1 подп.
#
# Канал 25 : 1 подп.
#
# Канал 26 : 1 подп.
#
# Канал 27 : 1 подп.
#
# Канал 28 : 435 подп.
#
# Канал 29 : 1 подп.
#
# Канал 30 : 350 подп.
#
# Канал 31 : 432 подп.
#
# Канал 32 : 1 подп.
#
# Канал 33 : 263 подп.
#
# Канал 34 : 1 подп.
#
# Канал 35 : 1 подп.
#
# Канал 36 : 1 подп.
#
# Канал 38 : 251 подп.
#
# Канал 39 : 407 подп.
#
# Канал 40 : 1 подп.
#
# Канал 41 : 1 подп.
#
# Канал 42 : 285 подп.
#
# Канал 43 : 1 подп.
#
# Канал 44 : 1 подп.
#
# Канал 45 : 251 подп.
#
# Канал 46 : 1 подп.
#
# Канал 47 : 328 подп.
#
# Канал 48 : 1 подп.
#
# Канал 49 : 1 подп.
#
# Канал 50 : 1 подп.
#
# Канал 51 : 1 подп.
#
# Канал 52 : 1 подп.
#
# Канал 53 : 1 подп.
#
# Канал 54 : 1 подп.
#
# Канал 55 : 297 подп.
#
# Канал 56 : 254 подп.
#
# Канал 57 : 1 подп.
#
# Канал 58 : 1 подп.
#
# Канал 59 : 1 подп.
#
# Канал 60 : 1 подп.
#
# Канал 61 : 1 подп.
#
# Канал 62 : 260 подп.
#
# Канал 63 : 1 подп.
#
# Канал 64 : 1 подп.
#
# Канал 65 : 1 подп.
#
# Канал 66 : 285 подп.
#
# Канал 67 : 1 подп.
#
# Канал 68 : 288 подп.
#
# Канал 69 : 1 подп.
#
# Канал 70 : 305 подп.
#
# Канал 71 : 1 подп.
#
# Канал 72 : 1 подп.
#
# Канал 73 : 1 подп.
#
# Канал 74 : 1 подп.
#
# Канал 75 : 1 подп.
#
# Канал 76 : 1 подп.
#
# Канал 77 : 1 подп.
#
# Канал 78 : 1 подп.
#
# Канал 79 : 1 подп.
#
# Канал 80 : 1 подп.
#
# Канал 81 : 1 подп.
#
# Канал 82 : 1 подп.
#
# Канал 83 : 1 подп.
#
# Канал 84 : 272 подп.
#
# Канал 85 : 257 подп.
#
# Канал 86 : 1 подп.
#
# Канал 87 : 278 подп.
#
# Канал 88 : 1 подп.
#
# Канал 89 : 1 подп.
#
# Канал 90 : 250 подп.
#
# Канал 91 : 268 подп.
#
# Канал 92 : 1 подп.
#
# Канал 93 : 1 подп.
#
# Канал 94 : 1 подп.
#
# Канал 95 : 1 подп.
#
# Канал 96 : 270 подп.
#
# Канал 97 : 1 подп.
#
# Канал 98 : 1 подп.
#
# Канал 99 : 1 подп.
